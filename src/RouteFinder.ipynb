# %%
import heapq, random


class PriorityQueue:
    """
    Implements a priority queue data structure. Each inserted item
    has a priority associated with it and the client is usually interested
    in quick retrieval of the lowest-priority item in the queue. This
    data structure allows O(1) access to the lowest-priority item.
    """

    def __init__(self):
        self.heap = []
        self.count = 0

    def push(self, item, priority):
        entry = (priority, self.count, item)
        heapq.heappush(self.heap, entry)
        self.count += 1

    def pop(self):
        (_, _, item) = heapq.heappop(self.heap)
        return item

    def isEmpty(self):
        return len(self.heap) == 0

    def update(self, item, priority):
        # If item already in priority queue with higher priority, update its priority and rebuild the heap.
        # If item already in priority queue with equal or lower priority, do nothing.
        # If item not in priority queue, do the same thing as self.push.
        for index, (p, c, i) in enumerate(self.heap):
            if i == item:
                if p <= priority:
                    break
                del self.heap[index]
                self.heap.append((priority, c, item))
                heapq.heapify(self.heap)
                break
        else:
            self.push(item, priority)

# %%
class Person:
    def __init__(self, height: int) -> None:
        """
        Represents a person class to get their
        height: height in inches rounded to nearest whole number
        """
        self.height = height
        self.wingspan = height * 1.06
        self.reach = height * 1.35
        self.leg_length = height * 0.5

# %%
class Hold:
    """
    Represents a hold in the route
    Has an x,y coordinate, a difficulty rating obtained from the model, a width and height, and an angle obtained from another model.
    """

    def __init__(
        self, x: int, y: int, diff: float, width: float, height: float, angle: int
    ):
        # Coords = middle of the bounding box
        self.x = x
        self.y = y
        self.diff = diff
        self.width = width
        self.height = height
        self.angle = angle

    def get_top_left(self):
        return (self.coords[0] - self.width / 2, self.coords[1] - self.height / 2)

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y

    def __gt__(self, other):
        return self.y > other.y

    def __lt__(self, other):
        return self.y < other.y

    def __ge__(self, other):
        return self.y >= other.y

    def __le__(self, other):
        return self.y <= other.y

    def __repr__(self):
        return f"""Hold: Top left at {self.x}, {self.y}
                Width = {self.width}, Height = {self.height}
                Difficulty = {round(self.diff, 2)}/10, Angle = {self.angle} degrees\n"""

# %%
from enum import Enum


class LimbName(Enum):
    """
    Class for limb names
    """

    LEFT_HAND = "Left Hand"
    RIGHT_HAND = "Right Hand"
    LEFT_LEG = "Left Leg"
    RIGHT_LEG = "Right Leg"

# %%
class Limb:
    def __init__(self, name: LimbName, strength: int, flexibility: int, hold: Hold):
        self.name, self.strength, self.flexibility, self.hold = (
            name,
            strength,
            flexibility,
            hold,
        )

    def __repr__(self):
        return f"{self.name} at {self.hold}"

# %%
class Route:
    def __init__(self, holds: Hold, start1: Hold, start2: Hold, finish: Hold):
        self.holds = holds
        self.start_hold1 = start1
        self.start_hold2 = start2
        self.finish_hold = finish

# %%
# import required module
from PIL import Image


class ImageAttributes:
    def __init__(self, path):
        self.path = path
        img = Image.open(path)
        self.width = img.width
        self.height = img.height

# %%
import math
from copy import copy

import numpy as np


class State:
    def __init__(
        self,
        lf: Limb,
        rf: Limb,
        lh: Limb,
        rh: Limb,
        person: Person,
        route: Route,
        image_attributes: ImageAttributes,
    ):
        self.lf, self.rf, self.lh, self.rh = lf, rf, lh, rh
        self.person = person
        self.moves = []
        self.costs = []
        self.route = route
        self.wall_height_inches = (
            156  # Represents real height of wall <- need to measure
        )
        self.image_attributes = image_attributes
        self.wall_height_pixels = self.image_attributes.height

    # Not sure where to put this
    def inches_to_pixels(self, inches: int):
        return (self.wall_height_pixels / self.wall_height_inches) * inches

    def __eq__(self, other):
        return (
            self.lf.hold == other.lf.hold
            and self.rf.hold == other.rf.hold
            and self.rh.hold == other.rh.hold
            and self.lh.hold == other.lh.hold
        ) or (
            self.lf.hold == other.rf.hold
            and self.rf.hold == other.lf.hold
            and self.rh.hold == other.lh.hold
            and self.lh.hold == other.rh.hold
        )

    def __repr__(self):
        return f"{self.moves}"

    def get_successors(self):
        succs = []
        limbs = [self.lf, self.rf, self.lh, self.rh]
        for i in range(len(limbs)):
            neighs = self.get_neighbors(limbs[i])
            for neigh in neighs:
                # print("Hi neighbor")
                new_state = copy(self)
                if i == 0:
                    new_state.lf = Limb(LimbName.LEFT_LEG, 2.5, 8, neigh)
                    action = (self.lf, neigh)
                if i == 1:
                    new_state.rf = Limb(LimbName.RIGHT_LEG, 2.5, 8, neigh)
                    action = (self.rf, neigh)
                if i == 2:
                    new_state.lh = Limb(LimbName.LEFT_HAND, 8, 2, neigh)
                    action = (self.lh, neigh)
                if i == 3:
                    new_state.rh = Limb(LimbName.RIGHT_HAND, 8, 2, neigh)
                    action = (self.rh, neigh)
                succs.append((new_state, action))
        # print(succs)
        return succs

    def get_neighbors(self, limb):
        neighbors = []
        for hold in self.route.holds:
            if not hold == limb.hold:
                if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                    # print("Checking leg neighbors")
                    # print(f"Height diff: {abs(hold.y - limb.hold.y)}")
                    # print(f"Leg length: {self.inches_to_pixels(self.person.leg_length)}")
                    # low_arm is max because pixels go from top to bottom
                    low_arm = max([self.lh.hold.y, self.rh.hold.y])
                    if (
                        0
                        < limb.hold.y - hold.y
                        < self.inches_to_pixels(self.person.leg_length)
                        and abs(hold.x - limb.hold.x)
                        < self.inches_to_pixels(self.person.leg_length)
                        and hold.y > low_arm
                    ):
                        neighbors.append(hold)
                elif limb.name in [LimbName.LEFT_HAND, LimbName.RIGHT_HAND]:
                    # print("Checking arm neighbors")
                    # print("HAND TIME 1")
                    upper_leg, lower_leg = sorted([self.lf.hold.y, self.rf.hold.y])
                    if (
                        abs(hold.x - limb.hold.x)
                        < self.inches_to_pixels(self.person.wingspan)
                        and lower_leg - hold.y
                        < self.inches_to_pixels(self.person.height * 0.8)
                        and hold.y < upper_leg
                        and 0 < limb.hold.y - hold.y
                    ):
                        # print(hold.y - upper_leg)
                        # print("HAND TIME 2")
                        neighbors.append(hold)
        return neighbors


def move_difficulty(state: State, limb: Limb, next_hold: Hold):
    """
    Evaluates the difficulty of a move
    state: the state that is being evaluated
    """

    move_diff = 0
    distance = math.sqrt(
        ((limb.hold.x - next_hold.x) ** 2) + ((limb.hold.y - next_hold.y) ** 2)
    )
    distance_diff = distance

    new_state = State(
        copy(state.lf),
        copy(state.rf),
        copy(state.lh),
        copy(state.rh),
        state.person,
        state.route,
        state.image_attributes,
    )
    new_state_limbs = [new_state.lh, new_state.rh, new_state.lf, new_state.rf]
    for new_state_limb in new_state_limbs:
        if new_state_limb.name == limb.name:
            new_state_limb.hold = None

    state_without_limb_difficulty = 0.3 * state_difficulty(new_state)
    distance_diff *= 0.3

    leg_flex_diff = 0
    hand_leg_diff = 0
    if limb.name in [LimbName.RIGHT_LEG, LimbName.LEFT_LEG]:
        leg_flex_diff += np.sqrt(
            (limb.hold.x - next_hold.x) ** 2 + (limb.hold.y - next_hold.y) ** 2
        )
        hand_leg_diff += (
            1000
            / np.sqrt(
                (next_hold.x - state.lh.hold.x) ** 2
                + (next_hold.y - state.lh.hold.y) ** 2
            )
        ) + (
            1000
            / (
                np.sqrt(
                    (next_hold.x - state.rh.hold.x) ** 2
                    + (next_hold.y - state.rh.hold.y) ** 2
                )
            )
        )

        if limb.name == LimbName.LEFT_LEG:
            leg_flex_diff += np.sqrt(
                (state.rf.hold.y - next_hold.y) ** 2
                + (state.rf.hold.x - next_hold.x) ** 2
            )

        elif limb.name == LimbName.RIGHT_LEG:
            leg_flex_diff += np.sqrt(
                (state.lf.hold.y - next_hold.y) ** 2
                + (state.lf.hold.x - next_hold.x) ** 2
            )

    leg_flex_diff *= 0.1
    hand_leg_diff *= 33.3
    distance_diff *= 1
    state_without_limb_difficulty *= 1

    move_diff += (
        leg_flex_diff + hand_leg_diff + distance_diff + state_without_limb_difficulty
    )

    print(
        f"move_diff = {move_diff}, legflexdiff = {leg_flex_diff}, distance_diff = {distance_diff}, statewolimbdiff = {state_without_limb_difficulty}, handlegdiff: {hand_leg_diff}"
    )
    return move_diff


def state_difficulty(state: State):
    """
    Finds the difficulty of a certain state
    state: the state that is being evaluated for difficulty
    """
    if state.lh.hold != None and state.rh.hold != None:
        average_hands_x = (state.lh.hold.x + state.rh.hold.x) / 2
        average_hands_y = (state.lh.hold.y + state.rh.hold.y) / 2
    else:
        if state.rh.hold == None:
            average_hands_x = state.lh.hold.x
            average_hands_y = state.lh.hold.y
        else:
            average_hands_y = state.rh.hold.y
            average_hands_x = state.rh.hold.x
    if state.lf.hold != None and state.rf.hold != None:
        average_legs_x = (state.lf.hold.x + state.rf.hold.x) / 2
        average_legs_y = (state.lf.hold.y + state.rf.hold.y) / 2
    else:
        if state.rf.hold == None:
            average_legs_x = state.lf.hold.x
            average_legs_y = state.lf.hold.y
        else:
            average_legs_y = state.rf.hold.y
            average_legs_x = state.rf.hold.x

    hands_difference_x = (
        abs(state.rh.hold.x - state.lh.hold.x)
        if state.lh.hold != None and state.rh.hold != None
        else 0
    )
    hands_difference_y = (
        abs(state.rh.hold.y - state.lh.hold.y)
        if state.lh.hold != None and state.rh.hold != None
        else 0
    )

    legs_difference_x = (
        abs(state.rf.hold.x - state.lf.hold.x)
        if state.lf.hold != None and state.rf.hold != None
        else 0
    )
    legs_difference_y = (
        abs(state.lf.hold.y - state.rf.hold.y)
        if state.lf.hold != None and state.rf.hold != None
        else 0
    )

    hands_difference_raw_x = (
        state.rh.hold.x - state.lh.hold.x
        if state.lh.hold != None and state.rh.hold != None
        else 0
    )
    legs_difference_raw_x = (
        state.rf.hold.x - state.lf.hold.x
        if state.lf.hold != None and state.rf.hold != None
        else 0
    )

    leg_match_diff = 0
    if (
        state.lf.hold != None
        and state.rf.hold != None
        and state.lf.hold.x - state.rf.hold.x == 0
    ):
        leg_match_diff = 250

    cross_diff = 0
    if hands_difference_raw_x < 0:
        cross_diff += 0.5 * abs(hands_difference_raw_x)
    if legs_difference_raw_x < 0:
        cross_diff += 100
    if hands_difference_raw_x < 0 and legs_difference_raw_x < 0:
        cross_diff *= 3

    diff = 0
    center_diff = abs(average_hands_x - average_legs_x)

    target_distance = state.inches_to_pixels(state.person.height * 0.85)

    max_legs_y = (
        min(state.lf.hold.y, state.rf.hold.y)
        if state.lf.hold is not None and state.rf.hold is not None
        else state.lf.hold.y
        if state.rf.hold is None
        else state.rf.hold.y
    )

    min_hands_y = (
        max(state.lh.hold.y, state.rh.hold.y)
        if state.lh.hold is not None and state.rh.hold is not None
        else state.lh.hold.y
        if state.rh.hold is None
        else state.rh.hold.y
    )

    distance_difference = 0
    if abs(max_legs_y - min_hands_y) < state.inches_to_pixels(36):
        distance_difference = 35

    distance_difference += target_distance - abs(max_legs_y - min_hands_y)

    scrunched_up_diff = distance_difference**2

    limb_strength_diff = 0
    angle_diff = 0

    # Check each limb and find the strength ratio for the holds
    for limb in [state.lh, state.rh, state.lf, state.rf]:
        if limb.hold != None:
            limb_strength_diff += limb.hold.diff / limb.strength
            if limb.name == LimbName.LEFT_HAND:
                if 315 >= limb.hold.angle >= 270:
                    angle_diff += 2
                elif 90 >= limb.hold.angle or limb.hold.angle > 315:
                    angle_diff += 1
                elif 180 >= limb.hold.angle > 90:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name == LimbName.RIGHT_HAND:
                if 90 >= limb.hold.angle >= 45:
                    angle_diff += 2
                elif 45 >= limb.hold.angle or limb.hold.angle > 270:
                    angle_diff += 1
                elif 270 >= limb.hold.angle > 180:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                if 90 <= limb.hold.angle <= 270:
                    angle_diff += 2
        else:
            limb_strength_diff += 6
    separation_diff = 0

    # If separated too far, make it harder
    if hands_difference_x > state.inches_to_pixels(0.8 * state.person.wingspan):
        separation_diff += 0.5 * hands_difference_x

    if (
        state.inches_to_pixels(10)
        <= abs(legs_difference_x)
        <= state.inches_to_pixels(state.person.height * 0.7)
    ):
        separation_diff -= 3000

    # Weight all of the different difficulties to balance them out
    center_diff *= 0.2
    scrunched_up_diff *= 0.0005
    angle_diff *= 1
    limb_strength_diff *= 3
    separation_diff *= 0.05
    cross_diff *= 0.5
    leg_match_diff *= 1.2
    diff += (
        center_diff
        + scrunched_up_diff
        + limb_strength_diff
        + separation_diff
        + leg_match_diff
        + cross_diff
    )
    print(
        f"state_diff  {diff}, center = {center_diff}, scrunched = {scrunched_up_diff}, strength = {limb_strength_diff}, cross = {cross_diff}, separation: {separation_diff}, legmatch: {leg_match_diff}"
    )
    return diff

# %%
import numpy as np
from copy import copy


class RouteFinder:
    """
    Class to find the route of a wall
    Takes in a state and gets the person's reach from that
    """

    WALL_HEIGHT = 180

    def __init__(self, state):
        self.state = state
        self.reach = state.person.reach

    def get_cost_value(self, costs):
        """
        Helper function used to square the costs in the list of costs
        """
        return sum([cost for cost in costs]) + 250 * len(costs)

    def uniform_cost_search(self):
        """
        Search function to find the best route
        """
        explored = []
        frontier = PriorityQueue()
        num = 0
        frontier.push(self.state, 0)
        while not frontier.isEmpty():
            cur_state = frontier.pop()
            explored.append(cur_state)
            if (
                cur_state.lh.hold == self.state.route.finish_hold
                and cur_state.rh.hold == self.state.route.finish_hold
            ):
                # What every good rock climber says at the top
                print("TAAAAAAAAAAAAAAKE")
                print("costs:", cur_state.costs)
                print("avg:", np.mean(cur_state.costs))
                print("total_cost:", self.get_cost_value(cur_state.costs))
                return cur_state.moves
            for next_state, action in cur_state.get_successors():
                if next_state not in explored:
                    num += 1
                    if num % 500 == 0:
                        print(
                            f"Checking state #{num} with move length {len(cur_state.moves)}"
                        )
                    next_state.costs = copy(cur_state.costs)
                    next_state.costs.append(
                        state_difficulty(next_state)
                        + move_difficulty(cur_state, action[0], action[1])
                    )
                    next_state.moves = copy(cur_state.moves)
                    next_state.moves.append(action)
                    if next_state in [tup[2] for tup in frontier.heap]:
                        frontier.update(
                            next_state, self.get_cost_value(next_state.costs)
                        )
                    else:
                        frontier.push(next_state, self.get_cost_value(next_state.costs))
        return []

# %%
import get_holds, hold_finder, diff_angle
from get_holds import get_holds_array
import importlib

importlib.reload(get_holds)
importlib.reload(hold_finder)
importlib.reload(diff_angle)

red_path = "../images/walls/redroute.jpg"
purple_path = "../images/walls/purpleroute.jpg"
green_path = "../images/walls/greencropped.jpg"
blue_path = "../images/walls/bluevb.jpg"

blue_holds = get_holds_array(blue_path, [210, 10, 30], 30)
blue_holds.sort()

blue_image = ImageAttributes(path=blue_path)

# red_holds = get_holds_array(red_path, [0, 20, 30], 10)
# red_holds.sort()

# purple_holds = get_holds_array(purple_path, [270, 5, 21], 50)
# purple_holds.sort()

# green_holds = get_holds_array(green_path, [120, 10, 20], 40)
# green_holds.sort()

# green_image = ImageAttributes(path=green_path)
# print(green_image.height)
# red_image = ImageAttributes(path=red_path)
# purple_image = ImageAttributes(path=purple_path)
# Out:
# image 1/1 /Users/liam/courses/year4/ai_cs4100/AI-Climbing/src/../images/walls/bluevb.jpg: 1280x544 50 holds, 144.6ms
# Speed: 8.0ms preprocess, 144.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 544)
#
# 0: 64x64 six 0.41, four 0.21, three 0.13, two 0.12, one 0.09, 3.7ms
# Speed: 1.3ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.48, six 0.41, five 0.04, four 0.02, two 0.01, 2.0ms
# Speed: 1.0ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.70, two 0.15, seven 0.04, eight 0.03, one 0.02, 2.3ms
# Speed: 0.8ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.43, six 0.25, three 0.19, four 0.11, seven 0.01, 2.4ms
# Speed: 0.8ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.49, two 0.18, seven 0.10, eight 0.07, four 0.04, 1.9ms
# Speed: 0.9ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.47, six 0.14, four 0.10, seven 0.08, one 0.06, 7.0ms
# Speed: 0.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.32, downclimb 0.18, two 0.16, eight 0.09, six 0.06, 2.5ms
# Speed: 0.9ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.89, four 0.07, ten 0.02, five 0.01, nine 0.00, 2.9ms
# Speed: 0.6ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.70, two 0.12, four 0.12, three 0.03, one 0.01, 2.1ms
# Speed: 1.0ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.29, eight 0.27, downclimb 0.13, six 0.10, nine 0.04, 2.5ms
# Speed: 0.9ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.20, eight 0.16, six 0.16, two 0.16, nine 0.09, 1.9ms
# Speed: 0.9ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.22, two 0.18, five 0.17, one 0.15, three 0.09, 2.5ms
# Speed: 1.0ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.87, nine 0.08, eight 0.01, four 0.01, two 0.01, 2.1ms
# Speed: 0.9ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.38, eight 0.19, six 0.11, two 0.09, downclimb 0.06, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.37, four 0.18, six 0.13, tag 0.10, five 0.06, 2.7ms
# Speed: 0.5ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 tag 0.98, downclimb 0.01, six 0.00, nine 0.00, seven 0.00, 2.1ms
# Speed: 0.9ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 tag 0.67, six 0.13, seven 0.08, two 0.04, eight 0.03, 2.0ms
# Speed: 0.9ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.41, two 0.35, seven 0.05, ten 0.05, four 0.03, 3.4ms
# Speed: 0.9ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.41, four 0.21, three 0.13, two 0.12, one 0.09, 2.6ms
# Speed: 1.1ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.64, five 0.13, ten 0.09, three 0.05, four 0.04, 1.9ms
# Speed: 0.5ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.37, six 0.21, three 0.20, two 0.15, five 0.04, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.59, four 0.19, five 0.09, two 0.05, eight 0.02, 2.4ms
# Speed: 0.7ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.56, eight 0.16, nine 0.13, ten 0.09, two 0.03, 1.9ms
# Speed: 0.6ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.44, four 0.16, eight 0.12, three 0.10, two 0.06, 2.5ms
# Speed: 0.9ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.34, eight 0.28, four 0.10, nine 0.06, two 0.06, 2.4ms
# Speed: 0.6ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.48, six 0.41, five 0.04, four 0.02, two 0.01, 1.9ms
# Speed: 0.7ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.33, ten 0.27, six 0.21, five 0.14, three 0.01, 1.9ms
# Speed: 0.5ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, four 0.29, seven 0.02, two 0.02, eight 0.02, 2.2ms
# Speed: 0.6ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.30, four 0.18, nine 0.17, five 0.12, ten 0.11, 1.9ms
# Speed: 0.6ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.68, seven 0.12, ten 0.06, eight 0.04, nine 0.04, 3.5ms
# Speed: 0.7ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.46, four 0.22, five 0.10, seven 0.09, three 0.05, 2.6ms
# Speed: 0.6ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.46, three 0.22, two 0.11, nine 0.07, seven 0.04, 1.8ms
# Speed: 0.6ms preprocess, 1.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.70, two 0.15, seven 0.04, eight 0.03, one 0.02, 2.6ms
# Speed: 0.6ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.33, ten 0.22, five 0.17, three 0.08, six 0.08, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.47, three 0.28, two 0.17, four 0.07, nine 0.01, 2.1ms
# Speed: 0.6ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.26, two 0.20, seven 0.10, four 0.10, three 0.10, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.47, two 0.46, eight 0.02, seven 0.01, three 0.01, 2.1ms
# Speed: 0.6ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.52, two 0.13, four 0.08, eight 0.08, five 0.05, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.46, three 0.25, six 0.11, two 0.11, seven 0.03, 2.1ms
# Speed: 0.6ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.43, six 0.25, three 0.19, four 0.11, seven 0.01, 2.7ms
# Speed: 0.7ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.46, three 0.13, four 0.10, five 0.10, ten 0.07, 2.2ms
# Speed: 0.7ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.73, four 0.15, two 0.06, five 0.02, ten 0.01, 2.2ms
# Speed: 0.6ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.26, four 0.21, five 0.14, two 0.11, seven 0.07, 2.9ms
# Speed: 0.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.23, four 0.22, six 0.17, ten 0.14, five 0.12, 2.4ms
# Speed: 0.6ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.45, two 0.26, five 0.10, seven 0.07, six 0.03, 3.3ms
# Speed: 0.8ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.28, six 0.23, two 0.12, five 0.12, seven 0.09, 1.8ms
# Speed: 0.5ms preprocess, 1.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.49, two 0.18, seven 0.10, eight 0.07, four 0.04, 2.7ms
# Speed: 0.7ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.56, ten 0.31, six 0.07, four 0.03, three 0.01, 2.0ms
# Speed: 0.6ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.29, six 0.25, seven 0.15, two 0.08, eight 0.07, 2.2ms
# Speed: 0.6ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.58, nine 0.16, seven 0.10, three 0.07, five 0.04, 2.2ms
# Speed: 0.7ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.69, eight 0.15, seven 0.10, two 0.03, downclimb 0.01, 2.7ms
# Speed: 0.6ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.42, five 0.35, seven 0.09, four 0.05, nine 0.02, 1.9ms
# Speed: 0.8ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.38, six 0.21, two 0.16, seven 0.09, three 0.09, 2.6ms
# Speed: 0.7ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.47, six 0.14, four 0.10, seven 0.08, one 0.06, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.40, two 0.28, four 0.16, ten 0.08, seven 0.03, 2.8ms
# Speed: 0.6ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, four 0.16, two 0.12, three 0.09, five 0.00, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.35, two 0.27, five 0.17, three 0.15, eight 0.02, 2.8ms
# Speed: 0.6ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, two 0.14, eight 0.13, four 0.06, nine 0.02, 3.5ms
# Speed: 0.9ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.24, five 0.19, eight 0.12, seven 0.12, three 0.11, 2.5ms
# Speed: 0.6ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.44, four 0.32, six 0.16, three 0.03, two 0.02, 5.7ms
# Speed: 0.6ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.32, downclimb 0.18, two 0.16, eight 0.09, six 0.06, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.20, nine 0.17, eight 0.16, five 0.12, three 0.11, 3.0ms
# Speed: 0.7ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.37, two 0.23, three 0.17, eight 0.11, seven 0.07, 2.4ms
# Speed: 0.6ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.58, seven 0.29, four 0.07, eight 0.04, five 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.37, two 0.31, eight 0.16, ten 0.04, six 0.04, 1.9ms
# Speed: 0.8ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.46, nine 0.34, ten 0.05, three 0.03, four 0.03, 3.7ms
# Speed: 0.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.74, seven 0.08, two 0.08, three 0.05, nine 0.02, 2.9ms
# Speed: 0.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.89, four 0.07, ten 0.02, five 0.01, nine 0.00, 2.9ms
# Speed: 0.6ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.35, two 0.27, six 0.13, ten 0.10, three 0.04, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.74, six 0.20, seven 0.02, five 0.02, three 0.01, 2.6ms
# Speed: 0.9ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.87, five 0.04, two 0.04, six 0.02, four 0.01, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.98, four 0.01, nine 0.00, two 0.00, ten 0.00, 3.5ms
# Speed: 0.6ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.91, two 0.04, five 0.02, seven 0.01, six 0.01, 2.3ms
# Speed: 0.8ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, two 0.23, three 0.07, four 0.06, tag 0.00, 4.5ms
# Speed: 0.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.70, two 0.12, four 0.12, three 0.03, one 0.01, 2.0ms
# Speed: 0.9ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.71, four 0.17, six 0.05, five 0.03, three 0.01, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.29, four 0.27, two 0.19, five 0.14, three 0.08, 2.5ms
# Speed: 0.7ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.72, two 0.10, six 0.07, five 0.06, seven 0.01, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.76, eight 0.17, four 0.03, two 0.02, seven 0.02, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, four 0.03, two 0.03, seven 0.03, five 0.02, 2.4ms
# Speed: 1.0ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.52, three 0.24, two 0.12, nine 0.06, tag 0.02, 1.9ms
# Speed: 0.6ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.29, eight 0.27, downclimb 0.13, six 0.10, nine 0.04, 2.5ms
# Speed: 0.9ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.37, four 0.19, ten 0.17, seven 0.11, six 0.05, 2.2ms
# Speed: 0.6ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.58, three 0.18, six 0.09, seven 0.06, two 0.04, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.65, seven 0.20, nine 0.08, eight 0.03, six 0.02, 2.2ms
# Speed: 0.7ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.83, eight 0.05, ten 0.04, downclimb 0.02, two 0.02, 3.1ms
# Speed: 0.8ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.30, ten 0.18, six 0.18, five 0.17, seven 0.06, 2.5ms
# Speed: 0.5ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.44, eight 0.16, seven 0.12, two 0.09, nine 0.05, 2.6ms
# Speed: 0.5ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.20, eight 0.16, six 0.16, two 0.16, nine 0.09, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.25, eight 0.19, four 0.14, nine 0.11, two 0.10, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.34, six 0.15, seven 0.12, two 0.12, eight 0.10, 2.0ms
# Speed: 0.8ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.44, eight 0.25, four 0.11, ten 0.06, two 0.04, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.35, seven 0.28, nine 0.20, six 0.10, four 0.02, 2.7ms
# Speed: 0.9ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, five 0.06, nine 0.04, eight 0.02, two 0.02, 2.5ms
# Speed: 0.7ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.41, two 0.22, six 0.17, seven 0.13, nine 0.04, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.22, two 0.18, five 0.17, one 0.15, three 0.09, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.33, ten 0.22, five 0.22, seven 0.08, four 0.07, 2.3ms
# Speed: 0.5ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.67, three 0.14, seven 0.09, four 0.08, two 0.01, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.51, two 0.18, ten 0.12, four 0.08, seven 0.05, 2.2ms
# Speed: 0.7ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.42, six 0.15, nine 0.11, eight 0.09, seven 0.09, 3.3ms
# Speed: 0.8ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.34, seven 0.24, five 0.18, four 0.08, ten 0.07, 2.3ms
# Speed: 0.7ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.79, seven 0.12, two 0.03, six 0.03, three 0.02, 3.5ms
# Speed: 0.6ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.87, nine 0.08, eight 0.01, four 0.01, two 0.01, 2.0ms
# Speed: 0.7ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.43, ten 0.16, five 0.11, seven 0.09, two 0.08, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.71, two 0.18, three 0.07, four 0.02, nine 0.01, 2.4ms
# Speed: 0.8ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.49, seven 0.14, ten 0.08, eight 0.07, six 0.05, 2.5ms
# Speed: 0.5ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.38, six 0.28, eight 0.16, ten 0.07, nine 0.05, 2.2ms
# Speed: 0.5ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.25, four 0.23, five 0.16, seven 0.09, three 0.09, 2.0ms
# Speed: 0.6ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.45, two 0.44, four 0.03, seven 0.03, eight 0.02, 2.9ms
# Speed: 0.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.38, eight 0.19, six 0.11, two 0.09, downclimb 0.06, 2.5ms
# Speed: 0.7ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.57, four 0.15, seven 0.10, eight 0.05, nine 0.05, 2.5ms
# Speed: 0.6ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.35, two 0.26, three 0.24, six 0.04, eight 0.04, 2.4ms
# Speed: 0.6ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.51, seven 0.17, nine 0.15, eight 0.07, ten 0.05, 3.1ms
# Speed: 0.8ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.83, two 0.06, eight 0.04, downclimb 0.03, ten 0.02, 2.0ms
# Speed: 0.8ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.86, seven 0.07, ten 0.02, eight 0.02, four 0.01, 3.7ms
# Speed: 0.6ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.52, four 0.32, seven 0.07, two 0.05, nine 0.01, 1.9ms
# Speed: 0.7ms preprocess, 1.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.37, four 0.18, six 0.13, tag 0.10, five 0.06, 3.7ms
# Speed: 1.0ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.58, tag 0.14, four 0.06, ten 0.06, eight 0.04, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.50, two 0.21, four 0.13, seven 0.09, one 0.02, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.38, ten 0.28, four 0.14, two 0.04, seven 0.04, 2.5ms
# Speed: 0.7ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.77, two 0.11, eight 0.04, three 0.03, seven 0.02, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.96, ten 0.01, seven 0.01, four 0.01, two 0.00, 2.9ms
# Speed: 0.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.66, four 0.10, six 0.10, seven 0.06, nine 0.03, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.41, two 0.35, seven 0.05, ten 0.05, four 0.03, 2.4ms
# Speed: 0.8ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.37, two 0.36, five 0.11, seven 0.08, three 0.03, 2.7ms
# Speed: 0.4ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.54, six 0.19, two 0.14, four 0.05, five 0.02, 2.0ms
# Speed: 0.8ms preprocess, 2.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.38, four 0.17, seven 0.12, five 0.10, ten 0.07, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.74, two 0.12, ten 0.03, five 0.03, four 0.02, 1.8ms
# Speed: 0.8ms preprocess, 1.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.29, four 0.21, three 0.20, five 0.13, seven 0.12, 2.5ms
# Speed: 0.6ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.20, three 0.18, five 0.16, two 0.16, eight 0.07, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running

# %%
def move_to_text(action, route):
    output = "- Move your "
    if action[0].name == LimbName.LEFT_LEG:
        output += "left leg "
    elif action[0].name == LimbName.LEFT_HAND:
        output += "left hand "
    elif action[0].name == LimbName.RIGHT_LEG:
        output += "right leg "
    elif action[0].name == LimbName.RIGHT_HAND:
        output += "right hand "
    output += "to hold number "
    output += str(route.holds.index(action[1]))
    output += " from the top"
    return output

# %%
holds = blue_holds

print(len(holds))
for i in range(len(holds)):
    print(f"{i}: {holds[i].x}, {holds[i].y}, {holds[i].diff}")
# Out:
# 16
# 0: 726.4537353515625, 671.9322509765625, 5.423205852508545
# 1: 669.379150390625, 946.1433715820312, 4.7929887771606445
# 2: 583.6227416992188, 1060.96240234375, 3.958439350128174
# 3: 539.9481201171875, 1326.082763671875, 5.150473117828369
# 4: 458.31268310546875, 1601.9052734375, 4.290992736816406
# 5: 939.6136474609375, 1641.247802734375, 6.440840244293213
# 6: 371.77130126953125, 1704.085693359375, 3.4617176055908203
# 7: 761.905029296875, 1854.95458984375, 6.437307834625244
# 8: 313.4748840332031, 1988.7144775390625, 3.498185396194458
# 9: 629.25927734375, 2256.31005859375, 5.954442977905273
# 10: 729.7620849609375, 2354.55517578125, 5.152984142303467
# 11: 446.43450927734375, 2471.044921875, 6.820249080657959
# 12: 858.0624389648438, 2665.64794921875, 6.412820816040039
# 13: 381.1021423339844, 2779.583740234375, 8.287285804748535
# 14: 798.894287109375, 2990.7744140625, 5.912786960601807
# 15: 314.7769775390625, 3097.7529296875, 5.333049297332764

# %%
holds = blue_holds
image = blue_image

route = Route(holds=holds, start1=holds[9], start2=holds[9], finish=holds[0])
lh = Limb(LimbName.LEFT_HAND, 2, 8, route.start_hold1)
rh = Limb(LimbName.RIGHT_HAND, 2, 8, route.start_hold2)
lf = Limb(LimbName.LEFT_LEG, 8, 5, holds[len(holds) - 1])
rf = Limb(LimbName.RIGHT_LEG, 8, 5, holds[len(holds) - 1])


# Test people of different heights
ondra = Person(70)
liam = Person(68)
rachel = Person(66)
anna = Person(63)
short = Person(59)
luisa = Person(64)
tall = Person(72)
giga = Person(76)
state1 = State(lf, rf, lh, rh, liam, route, image)
a_star1 = RouteFinder(state=state1)
results1 = a_star1.uniform_cost_search()

for action in results1:
    print(move_to_text(action, route))
# Out:
# state_diff  649.4763600147052, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 28.04752131700516, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 605.9883579540785, legflexdiff = 128.0775753548964, distance_diff = 192.11636303234457, statewolimbdiff = 49.64196022141533, handlegdiff: 236.15245934542233
# state_diff  277.9791214439178, center = 8.567919921875001, scrunched = 341.85259412257915, strength = 27.558607399463654, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 538.7488627782518, legflexdiff = 138.83426187256848, distance_diff = 208.25139280885267, statewolimbdiff = 49.64196022141533, handlegdiff: 142.0212478754153
# state_diff  390.2057015398159, center = 56.2639404296875, scrunched = 254.13379572421454, strength = 29.807965385913846, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 327.1454145778254, legflexdiff = 65.00174170045972, distance_diff = 97.50261255068958, statewolimbdiff = 49.64196022141533, handlegdiff: 114.99910010526077
# state_diff  67.31391077837827, center = 14.484729003906251, scrunched = 125.87061500153428, strength = 26.958566772937772, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 385.89249885966433, legflexdiff = 99.15926022937569, distance_diff = 148.73889034406352, statewolimbdiff = 49.64196022141533, handlegdiff: 88.35238806480979
# state_diff  599.4763600147052, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 28.04752131700516, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 605.9883579540785, legflexdiff = 128.0775753548964, distance_diff = 192.11636303234457, statewolimbdiff = 49.64196022141533, handlegdiff: 236.15245934542233
# state_diff  227.9791214439178, center = 8.567919921875001, scrunched = 341.85259412257915, strength = 27.558607399463654, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 538.7488627782518, legflexdiff = 138.83426187256848, distance_diff = 208.25139280885267, statewolimbdiff = 49.64196022141533, handlegdiff: 142.0212478754153
# state_diff  340.2057015398159, center = 56.2639404296875, scrunched = 254.13379572421454, strength = 29.807965385913846, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 327.1454145778254, legflexdiff = 65.00174170045972, distance_diff = 97.50261255068958, statewolimbdiff = 49.64196022141533, handlegdiff: 114.99910010526077
# state_diff  17.313910778378272, center = 14.484729003906251, scrunched = 125.87061500153428, strength = 26.958566772937772, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 385.89249885966433, legflexdiff = 99.15926022937569, distance_diff = 148.73889034406352, statewolimbdiff = 49.64196022141533, handlegdiff: 88.35238806480979
# state_diff  410.27480689845345, center = 31.318017578125, scrunched = 64.713518356898, strength = 14.243270963430405, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  458.541429757693, center = 62.896459960937506, scrunched = 64.713518356898, strength = 30.931451439857483, cross = 0.0, separation: 0.0, legmatch: 300.0
# move_diff = 261.73749093762274, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 137.56242892730788, handlegdiff: 0.0
# state_diff  489.22090522609017, center = 31.318017578125, scrunched = 64.713518356898, strength = 14.243270963430405, cross = 78.94609832763672, separation: 0.0, legmatch: 300.0
# state_diff  458.541429757693, center = 62.896459960937506, scrunched = 64.713518356898, strength = 30.931451439857483, cross = 0.0, separation: 0.0, legmatch: 300.0
# move_diff = 261.73749093762274, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 137.56242892730788, handlegdiff: 0.0
# state_diff  406.1600738203807, center = 1.3189697265625, scrunched = 521.6981319105906, strength = 33.14297218322754, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 615.9315225378997, legflexdiff = 126.83581308780354, distance_diff = 192.11636303234457, statewolimbdiff = 60.82688707232917, handlegdiff: 236.15245934542233
# state_diff  464.3504756304527, center = 39.843823242187504, scrunched = 341.85259412257915, strength = 32.65405826568603, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 513.5633057748148, legflexdiff = 102.46377801821768, distance_diff = 208.25139280885267, statewolimbdiff = 60.82688707232917, handlegdiff: 142.0212478754153
# state_diff  146.88942144900705, center = 7.85220947265625, scrunched = 254.13379572421454, strength = 34.903416252136225, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 352.6431199713946, legflexdiff = 79.3145202431151, distance_diff = 97.50261255068958, statewolimbdiff = 60.82688707232917, handlegdiff: 114.99910010526077
# state_diff  491.8516345938194, center = 33.927001953125, scrunched = 125.87061500153428, strength = 32.05401763916015, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 347.4977955958903, legflexdiff = 49.579630114687845, distance_diff = 148.73889034406352, statewolimbdiff = 60.82688707232917, handlegdiff: 88.35238806480979
# state_diff  544.9183281044551, center = 21.39794921875, scrunched = 647.4735754947253, strength = 26.046803390979765, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 864.6178043827299, legflexdiff = 149.11724853907856, distance_diff = 191.98926076209568, statewolimbdiff = 49.64196022141533, handlegdiff: 473.8693348601404
# state_diff  599.4763600147052, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 28.04752131700516, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 601.0213088857072, legflexdiff = 126.83581308780354, distance_diff = 188.39107623106602, statewolimbdiff = 49.64196022141533, handlegdiff: 236.15245934542233
# state_diff  227.9791214439178, center = 8.567919921875001, scrunched = 341.85259412257915, strength = 27.558607399463654, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 393.2669273608486, legflexdiff = 102.46377801821768, distance_diff = 99.13994124580032, statewolimbdiff = 49.64196022141533, handlegdiff: 142.0212478754153
# state_diff  340.2057015398159, center = 56.2639404296875, scrunched = 254.13379572421454, strength = 29.807965385913846, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 384.3965287484469, legflexdiff = 79.3145202431151, distance_diff = 140.4409481786557, statewolimbdiff = 49.64196022141533, handlegdiff: 114.99910010526077
# state_diff  12.303050210093318, center = 17.09371337890625, scrunched = 125.87061500153428, strength = 19.338721829652783, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  26.382246311520362, center = 14.484729003906251, scrunched = 125.87061500153428, strength = 36.02690230607986, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 132.08973590377096, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 7.914673893456108, handlegdiff: 0.0
# state_diff  91.24914853773004, center = 17.09371337890625, scrunched = 125.87061500153428, strength = 19.338721829652783, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  26.382246311520362, center = 14.484729003906251, scrunched = 125.87061500153428, strength = 36.02690230607986, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 132.08973590377096, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 7.914673893456108, handlegdiff: 0.0
# state_diff  650.7886960661693, center = 43.098193359375, scrunched = 521.6981319105906, strength = 35.992370796203616, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 628.7175946704594, legflexdiff = 95.57678390501808, distance_diff = 192.11636303234457, statewolimbdiff = 104.87198838767452, handlegdiff: 236.15245934542233
# state_diff  279.29145139186625, center = 1.9354003906250001, scrunched = 341.85259412257915, strength = 35.50345687866211, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 573.5997543632728, legflexdiff = 118.45512529133035, distance_diff = 208.25139280885267, statewolimbdiff = 104.87198838767452, handlegdiff: 142.0212478754153
# state_diff  641.51803759128, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 37.7528148651123, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 349.87457189385475, legflexdiff = 32.50087085022986, distance_diff = 97.50261255068958, statewolimbdiff = 104.87198838767452, handlegdiff: 114.99910010526077
# state_diff  196.88942144900705, center = 7.85220947265625, scrunched = 254.13379572421454, strength = 34.903416252136225, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 438.3565463041209, legflexdiff = 96.39327950757308, distance_diff = 148.73889034406352, statewolimbdiff = 104.87198838767452, handlegdiff: 88.35238806480979
# state_diff  544.9183281044551, center = 21.39794921875, scrunched = 647.4735754947253, strength = 26.046803390979765, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 828.5277481320677, legflexdiff = 140.09473447641298, distance_diff = 164.92171857409897, statewolimbdiff = 49.64196022141533, handlegdiff: 473.8693348601404
# state_diff  599.4763600147052, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 28.04752131700516, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 475.98519215456537, legflexdiff = 95.57678390501808, distance_diff = 94.61398868270962, statewolimbdiff = 49.64196022141533, handlegdiff: 236.15245934542233
# state_diff  227.9791214439178, center = 8.567919921875001, scrunched = 341.85259412257915, strength = 27.558607399463654, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 457.23231645329935, legflexdiff = 118.45512529133035, distance_diff = 147.11398306513837, statewolimbdiff = 49.64196022141533, handlegdiff: 142.0212478754153
# state_diff  301.0074142137184, center = 24.685498046875, scrunched = 254.13379572421454, strength = 22.188120442628858, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  349.274037072958, center = 56.2639404296875, scrunched = 254.13379572421454, strength = 38.876300919055936, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 228.95727313220223, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 104.78221112188739, handlegdiff: 0.0
# state_diff  379.9535125413551, center = 24.685498046875, scrunched = 254.13379572421454, strength = 22.188120442628858, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# state_diff  349.274037072958, center = 56.2639404296875, scrunched = 254.13379572421454, strength = 38.876300919055936, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 228.95727313220223, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 104.78221112188739, handlegdiff: 0.0
# state_diff  610.2780726886076, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 542.7099367195739, legflexdiff = 128.0775753548964, distance_diff = 192.11636303234457, statewolimbdiff = 37.88247402358609, handlegdiff: 184.6335243087469
# state_diff  284.80187903969534, center = 23.0105224609375, scrunched = 341.85259412257915, strength = 19.938762456178665, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 494.30745509214245, legflexdiff = 138.83426187256848, distance_diff = 208.25139280885267, statewolimbdiff = 37.88247402358609, handlegdiff: 109.33932638713524
# state_diff  351.0074142137184, center = 24.685498046875, scrunched = 254.13379572421454, strength = 22.188120442628858, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 299.8388487669351, legflexdiff = 65.00174170045972, distance_diff = 97.50261255068958, statewolimbdiff = 37.88247402358609, handlegdiff: 99.4520204921997
# state_diff  62.30305021009332, center = 17.09371337890625, scrunched = 125.87061500153428, strength = 19.338721829652783, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 359.86404268052405, legflexdiff = 99.15926022937569, distance_diff = 148.73889034406352, statewolimbdiff = 37.88247402358609, handlegdiff: 74.08341808349871
# state_diff  560.2780726886076, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 542.7099367195739, legflexdiff = 128.0775753548964, distance_diff = 192.11636303234457, statewolimbdiff = 37.88247402358609, handlegdiff: 184.6335243087469
# state_diff  234.80187903969534, center = 23.0105224609375, scrunched = 341.85259412257915, strength = 19.938762456178665, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 494.30745509214245, legflexdiff = 138.83426187256848, distance_diff = 208.25139280885267, statewolimbdiff = 37.88247402358609, handlegdiff: 109.33932638713524
# state_diff  301.0074142137184, center = 24.685498046875, scrunched = 254.13379572421454, strength = 22.188120442628858, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 299.8388487669351, legflexdiff = 65.00174170045972, distance_diff = 97.50261255068958, statewolimbdiff = 37.88247402358609, handlegdiff: 99.4520204921997
# state_diff  12.303050210093318, center = 17.09371337890625, scrunched = 125.87061500153428, strength = 19.338721829652783, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 359.86404268052405, legflexdiff = 99.15926022937569, distance_diff = 148.73889034406352, statewolimbdiff = 37.88247402358609, handlegdiff: 74.08341808349871
# state_diff  311.13095648746366, center = 0.260418701171875, scrunched = 4.247111766146371, strength = 6.623426020145416, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  327.81913696389074, center = 0.260418701171875, scrunched = 4.247111766146371, strength = 23.311606496572495, cross = 0.0, separation: 0.0, legmatch: 300.0
# move_diff = 222.52080309948207, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 98.34574108916722, handlegdiff: 0.0
# state_diff  410.0389840758128, center = 4.59783935546875, scrunched = 521.6981319105906, strength = 33.743012809753424, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  431.1719403597618, center = 45.760632324218754, scrunched = 341.85259412257915, strength = 43.55871391296387, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 667.19026844629, legflexdiff = 109.5698639605946, distance_diff = 192.11636303234457, statewolimbdiff = 129.35158210792852, handlegdiff: 236.15245934542233
# state_diff  720.8673253390098, center = 45.760632324218754, scrunched = 341.85259412257915, strength = 33.254098892211914, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  431.1719403597618, center = 45.760632324218754, scrunched = 341.85259412257915, strength = 43.55871391296387, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 549.0413537284807, legflexdiff = 69.41713093628424, distance_diff = 208.25139280885267, statewolimbdiff = 129.35158210792852, handlegdiff: 142.0212478754153
# state_diff  229.29145139186625, center = 1.9354003906250001, scrunched = 341.85259412257915, strength = 35.50345687866211, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  431.1719403597618, center = 45.760632324218754, scrunched = 341.85259412257915, strength = 43.55871391296387, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 423.3921599691548, legflexdiff = 81.538865205276, distance_diff = 97.50261255068958, statewolimbdiff = 129.35158210792852, handlegdiff: 114.99910010526077
# state_diff  414.3504756304527, center = 39.843823242187504, scrunched = 341.85259412257915, strength = 32.65405826568603, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  431.1719403597618, center = 45.760632324218754, scrunched = 341.85259412257915, strength = 43.55871391296387, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 449.06913771342306, legflexdiff = 82.62627719662129, distance_diff = 148.73889034406352, statewolimbdiff = 129.35158210792852, handlegdiff: 88.35238806480979
# state_diff  544.9183281044551, center = 21.39794921875, scrunched = 647.4735754947253, strength = 26.046803390979765, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 743.2365479729656, legflexdiff = 118.77193443663748, distance_diff = 100.95331845477247, statewolimbdiff = 49.64196022141533, handlegdiff: 473.8693348601404
# state_diff  599.4763600147052, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 28.04752131700516, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 531.9575123768716, legflexdiff = 109.5698639605946, distance_diff = 136.5932288494392, statewolimbdiff = 49.64196022141533, handlegdiff: 236.15245934542233
# state_diff  234.80187903969534, center = 23.0105224609375, scrunched = 341.85259412257915, strength = 19.938762456178665, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  237.04745697705988, center = 8.567919921875001, scrunched = 341.85259412257915, strength = 36.62694293260574, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 195.28929910343282, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 71.11423709311796, handlegdiff: 0.0
# state_diff  313.74797736733206, center = 23.0105224609375, scrunched = 341.85259412257915, strength = 19.938762456178665, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  237.04745697705988, center = 8.567919921875001, scrunched = 341.85259412257915, strength = 36.62694293260574, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 195.28929910343282, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 71.11423709311796, handlegdiff: 0.0
# state_diff  427.4807318067832, center = 30.25947265625, scrunched = 521.6981319105906, strength = 25.523127239942554, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  226.71488768062477, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 571.6001667330825, legflexdiff = 126.83581308780354, distance_diff = 192.11636303234457, statewolimbdiff = 68.01446630418742, handlegdiff: 184.6335243087469
# state_diff  488.30907306998023, center = 71.42226562500001, scrunched = 341.85259412257915, strength = 25.034213322401044, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  226.71488768062477, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 488.06896351839305, legflexdiff = 102.46377801821768, distance_diff = 208.25139280885267, statewolimbdiff = 68.01446630418742, handlegdiff: 109.33932638713524
# state_diff  155.14359994322206, center = 23.726232910156252, scrunched = 254.13379572421454, strength = 27.28357130885124, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  226.71488768062477, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 344.28361959019173, legflexdiff = 79.3145202431151, distance_diff = 97.50261255068958, statewolimbdiff = 68.01446630418742, handlegdiff: 99.4520204921997
# state_diff  515.8102320333469, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 24.434172695875166, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  226.71488768062477, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 340.4164048464375, legflexdiff = 49.579630114687845, distance_diff = 148.73889034406352, statewolimbdiff = 68.01446630418742, handlegdiff: 74.08341808349871
# state_diff  526.0810271064826, center = 10.1804931640625, scrunched = 647.4735754947253, strength = 18.42695844769478, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 676.0105741110425, legflexdiff = 149.11724853907856, distance_diff = 191.98926076209568, statewolimbdiff = 37.88247402358609, handlegdiff: 297.0215907862822
# state_diff  560.2780726886076, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 537.7428876512025, legflexdiff = 126.83581308780354, distance_diff = 188.39107623106602, statewolimbdiff = 37.88247402358609, handlegdiff: 184.6335243087469
# state_diff  234.80187903969534, center = 23.0105224609375, scrunched = 341.85259412257915, strength = 19.938762456178665, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 348.8255196747394, legflexdiff = 102.46377801821768, distance_diff = 99.13994124580032, statewolimbdiff = 37.88247402358609, handlegdiff: 109.33932638713524
# state_diff  301.0074142137184, center = 24.685498046875, scrunched = 254.13379572421454, strength = 22.188120442628858, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 357.08996293755655, legflexdiff = 79.3145202431151, distance_diff = 140.4409481786557, statewolimbdiff = 37.88247402358609, handlegdiff: 99.4520204921997
# state_diff  -69.78008039586976, center = 48.672149658203125, scrunched = 19.828893059559316, strength = 11.718876886367799, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  -53.09189991944268, center = 48.672149658203125, scrunched = 19.828893059559316, strength = 28.407057362794873, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 108.24749203448204, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = -15.927569975832803, handlegdiff: 0.0
# state_diff  506.4268301344199, center = 30.25947265625, scrunched = 521.6981319105906, strength = 25.523127239942554, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  305.6609860082615, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 595.2839962313734, legflexdiff = 126.83581308780354, distance_diff = 192.11636303234457, statewolimbdiff = 91.69829580247844, handlegdiff: 184.6335243087469
# state_diff  825.1473680528904, center = 71.42226562500001, scrunched = 341.85259412257915, strength = 25.034213322401044, cross = 386.83829498291016, separation: 0.0, legmatch: 0.0
# state_diff  305.6609860082615, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 511.7527930166841, legflexdiff = 102.46377801821768, distance_diff = 208.25139280885267, statewolimbdiff = 91.69829580247844, handlegdiff: 109.33932638713524
# state_diff  234.08969827085878, center = 23.726232910156252, scrunched = 254.13379572421454, strength = 27.28357130885124, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  305.6609860082615, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 367.9674490884828, legflexdiff = 79.3145202431151, distance_diff = 97.50261255068958, statewolimbdiff = 91.69829580247844, handlegdiff: 99.4520204921997
# state_diff  594.7563303609836, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 24.434172695875166, cross = 78.94609832763672, separation: 0.0, legmatch: 300.0
# state_diff  305.6609860082615, center = 65.5054443359375, scrunched = 125.87061500153428, strength = 35.338828343153, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 364.1002343447285, legflexdiff = 49.579630114687845, distance_diff = 148.73889034406352, statewolimbdiff = 91.69829580247844, handlegdiff: 74.08341808349871
# state_diff  605.0271254341193, center = 10.1804931640625, scrunched = 647.4735754947253, strength = 18.42695844769478, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  205.22101173959035, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 699.6944036093336, legflexdiff = 149.11724853907856, distance_diff = 191.98926076209568, statewolimbdiff = 61.5663035218771, handlegdiff: 297.0215907862822
# state_diff  639.2241710162443, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# state_diff  205.22101173959035, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 561.4267171494936, legflexdiff = 126.83581308780354, distance_diff = 188.39107623106602, statewolimbdiff = 61.5663035218771, handlegdiff: 184.6335243087469
# state_diff  313.74797736733206, center = 23.0105224609375, scrunched = 341.85259412257915, strength = 19.938762456178665, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  205.22101173959035, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 372.5093491730304, legflexdiff = 102.46377801821768, distance_diff = 99.13994124580032, statewolimbdiff = 61.5663035218771, handlegdiff: 109.33932638713524
# state_diff  379.9535125413551, center = 24.685498046875, scrunched = 254.13379572421454, strength = 22.188120442628858, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# state_diff  205.22101173959035, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# move_diff = 380.77379243584755, legflexdiff = 79.3145202431151, distance_diff = 140.4409481786557, statewolimbdiff = 61.5663035218771, handlegdiff: 99.4520204921997
# state_diff  -69.78008039586976, center = 48.672149658203125, scrunched = 19.828893059559316, strength = 11.718876886367799, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  -53.09189991944268, center = 48.672149658203125, scrunched = 19.828893059559316, strength = 28.407057362794873, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 108.24749203448204, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = -15.927569975832803, handlegdiff: 0.0
# state_diff  213.90277771291773, center = 61.83790893554688, scrunched = 284.1615864807133, strength = 17.903282296657565, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  144.63175707466172, center = 97.08388061523438, scrunched = 19.828893059559316, strength = 27.71898339986801, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 495.45629251461816, legflexdiff = 126.83581308780354, distance_diff = 192.11636303234457, statewolimbdiff = 43.38952712239851, handlegdiff: 133.1145892720715
# state_diff  326.8060291531669, center = 103.00070190429688, scrunched = 156.39095886975394, strength = 17.414368379116056, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  144.63175707466172, center = 97.08388061523438, scrunched = 19.828893059559316, strength = 27.71898339986801, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 430.7621028483241, legflexdiff = 102.46377801821768, distance_diff = 208.25139280885267, statewolimbdiff = 43.38952712239851, handlegdiff: 76.6574048988552
# state_diff  9.15510467690649, center = 55.30466918945313, scrunched = 84.1867091218871, strength = 19.66372636556625, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  144.63175707466172, center = 97.08388061523438, scrunched = 19.828893059559316, strength = 27.71898339986801, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 304.1116007953418, legflexdiff = 79.3145202431151, distance_diff = 97.50261255068958, statewolimbdiff = 43.38952712239851, handlegdiff: 83.9049408791386
# state_diff  433.7271014273839, center = 97.08388061523438, scrunched = 19.828893059559316, strength = 16.81432775259018, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  144.63175707466172, center = 97.08388061523438, scrunched = 19.828893059559316, strength = 27.71898339986801, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 301.5224956833375, legflexdiff = 49.579630114687845, distance_diff = 148.73889034406352, statewolimbdiff = 43.38952712239851, handlegdiff: 59.81444810218763
# state_diff  281.3309317197471, center = 41.75892944335938, scrunched = 378.76488877197795, strength = 10.807113504409791, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  27.131063000963877, center = 0.260418701171875, scrunched = 4.247111766146371, strength = 22.62353253364563, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 469.4196749138874, legflexdiff = 149.11724853907856, distance_diff = 191.98926076209568, statewolimbdiff = 8.139318900289163, handlegdiff: 120.173846712424
# state_diff  310.3955897861485, center = 13.426171875000001, scrunched = 284.1615864807133, strength = 12.80783143043518, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  27.131063000963877, center = 0.260418701171875, scrunched = 4.247111766146371, strength = 22.62353253364563, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 456.4807974912302, legflexdiff = 126.83581308780354, distance_diff = 188.39107623106602, statewolimbdiff = 8.139318900289163, handlegdiff: 133.1145892720715
# state_diff  73.298835122882, center = 54.588958740234375, scrunched = 156.39095886975394, strength = 12.318917512893677, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  27.131063000963877, center = 0.260418701171875, scrunched = 4.247111766146371, strength = 22.62353253364563, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 286.40044306316236, legflexdiff = 102.46377801821768, distance_diff = 99.13994124580032, statewolimbdiff = 8.139318900289163, handlegdiff: 76.6574048988552
# state_diff  105.64792285365284, center = 6.8929382324218755, scrunched = 84.1867091218871, strength = 14.568275499343871, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  27.131063000963877, center = 0.260418701171875, scrunched = 4.247111766146371, strength = 22.62353253364563, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 311.79972820119855, legflexdiff = 79.3145202431151, distance_diff = 140.4409481786557, statewolimbdiff = 8.139318900289163, handlegdiff: 83.9049408791386
# state_diff  705.6296114902087, center = 27.013781738281253, scrunched = 647.4735754947253, strength = 31.142254257202147, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 818.5882669519668, legflexdiff = 118.97032644539823, distance_diff = 164.92171857409897, statewolimbdiff = 60.82688707232917, handlegdiff: 473.8693348601404
# state_diff  406.1600738203807, center = 1.3189697265625, scrunched = 521.6981319105906, strength = 33.14297218322754, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 485.9283567383863, legflexdiff = 94.33502163792522, distance_diff = 94.61398868270962, statewolimbdiff = 60.82688707232917, handlegdiff: 236.15245934542233
# state_diff  464.3504756304527, center = 39.843823242187504, scrunched = 341.85259412257915, strength = 32.65405826568603, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  202.75629024109725, center = 33.927001953125, scrunched = 125.87061500153428, strength = 42.958673286437985, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 432.0467594498624, legflexdiff = 82.08464143697957, distance_diff = 147.11398306513837, statewolimbdiff = 60.82688707232917, handlegdiff: 142.0212478754153
# state_diff  546.2306580524036, center = 14.765429687500001, scrunched = 647.4735754947253, strength = 33.99165287017823, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 889.7009104553088, legflexdiff = 118.97032644539823, distance_diff = 191.98926076209568, statewolimbdiff = 104.87198838767452, handlegdiff: 473.8693348601404
# state_diff  600.7886960661693, center = 43.098193359375, scrunched = 521.6981319105906, strength = 35.99237079620361, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 623.7505456020881, legflexdiff = 94.33502163792522, distance_diff = 188.39107623106602, statewolimbdiff = 104.87198838767452, handlegdiff: 236.15245934542233
# state_diff  229.29145139186625, center = 1.9354003906250001, scrunched = 341.85259412257915, strength = 35.50345687866211, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 428.11781894586966, legflexdiff = 82.08464143697957, distance_diff = 99.13994124580032, statewolimbdiff = 104.87198838767452, handlegdiff: 142.0212478754153
# state_diff  641.51803759128, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 37.7528148651123, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  349.57329462558175, center = 49.63142700195313, scrunched = 254.13379572421454, strength = 45.80807189941406, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 407.1256860644762, legflexdiff = 46.81364939288524, distance_diff = 140.4409481786557, statewolimbdiff = 104.87198838767452, handlegdiff: 114.99910010526077
# state_diff  155.14359994322206, center = 23.726232910156252, scrunched = 254.13379572421454, strength = 27.28357130885124, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  155.95775698214914, center = 7.85220947265625, scrunched = 254.13379572421454, strength = 43.971751785278315, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 170.96238910495958, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 46.78732709464474, handlegdiff: 0.0
# state_diff  234.08969827085878, center = 23.726232910156252, scrunched = 254.13379572421454, strength = 27.28357130885124, cross = 78.94609832763672, separation: -150.0, legmatch: 0.0
# state_diff  155.95775698214914, center = 7.85220947265625, scrunched = 254.13379572421454, strength = 43.971751785278315, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 170.96238910495958, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 46.78732709464474, handlegdiff: 0.0
# state_diff  892.4950122511667, center = 36.564953613281254, scrunched = 521.6981319105906, strength = 34.231926727294926, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  602.3107133543772, center = 36.564953613281254, scrunched = 521.6981319105906, strength = 44.04762783050538, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 673.0008240615282, legflexdiff = 64.0387876774482, distance_diff = 192.11636303234457, statewolimbdiff = 180.69321400631316, handlegdiff: 236.15245934542233
# state_diff  460.0389840758128, center = 4.59783935546875, scrunched = 521.6981319105906, strength = 33.743012809753424, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  602.3107133543772, center = 36.564953613281254, scrunched = 521.6981319105906, strength = 44.04762783050538, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 645.9140619100118, legflexdiff = 114.94820721943066, distance_diff = 208.25139280885267, statewolimbdiff = 180.69321400631316, handlegdiff: 142.0212478754153
# state_diff  600.7886960661693, center = 43.098193359375, scrunched = 521.6981319105906, strength = 35.99237079620361, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  602.3107133543772, center = 36.564953613281254, scrunched = 521.6981319105906, strength = 44.04762783050538, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 457.2337937400632, legflexdiff = 64.03886707779974, distance_diff = 97.50261255068958, statewolimbdiff = 180.69321400631316, handlegdiff: 114.99910010526077
# state_diff  456.1600738203807, center = 1.3189697265625, scrunched = 521.6981319105906, strength = 33.142972183227535, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  602.3107133543772, center = 36.564953613281254, scrunched = 521.6981319105906, strength = 44.04762783050538, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 530.1611479402296, legflexdiff = 112.37665552504319, distance_diff = 148.73889034406352, statewolimbdiff = 180.69321400631316, handlegdiff: 88.35238806480979
# state_diff  544.9183281044551, center = 21.39794921875, scrunched = 647.4735754947253, strength = 26.046803390979765, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  165.4732007380511, center = 62.896459960937506, scrunched = 64.713518356898, strength = 37.86322242021561, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 731.1682412014538, legflexdiff = 115.75485774375954, distance_diff = 91.90208837613866, statewolimbdiff = 49.64196022141533, handlegdiff: 473.8693348601404
# state_diff  560.2780726886076, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  608.5446955478473, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 37.11585685014725, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 306.73847067466903, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 182.56340866435417, handlegdiff: 0.0
# state_diff  639.2241710162443, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 78.94609832763672, separation: 0.0, legmatch: 0.0
# state_diff  608.5446955478473, center = 49.730706787109376, scrunched = 521.6981319105906, strength = 37.11585685014725, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 306.73847067466903, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 182.56340866435417, handlegdiff: 0.0
# state_diff  433.99758151534024, center = 36.176281738281254, scrunched = 521.6981319105906, strength = 26.12316786646843, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  455.1305377992893, center = 77.33907470703126, scrunched = 341.85259412257915, strength = 35.93886896967888, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 622.8589126414729, legflexdiff = 109.5698639605946, distance_diff = 192.11636303234457, statewolimbdiff = 136.53916133978677, handlegdiff: 184.6335243087469
# state_diff  744.8259227785373, center = 77.33907470703126, scrunched = 341.85259412257915, strength = 25.634253948926926, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  455.1305377992893, center = 77.33907470703126, scrunched = 341.85259412257915, strength = 35.93886896967888, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 523.5470114720589, legflexdiff = 69.41713093628424, distance_diff = 208.25139280885267, statewolimbdiff = 136.53916133978677, handlegdiff: 109.33932638713524
# state_diff  249.37924805014376, center = 29.643041992187502, scrunched = 341.85259412257915, strength = 27.883611935377118, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  455.1305377992893, center = 77.33907470703126, scrunched = 341.85259412257915, strength = 35.93886896967888, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 415.032659587952, legflexdiff = 81.538865205276, distance_diff = 97.50261255068958, statewolimbdiff = 136.53916133978677, handlegdiff: 99.4520204921997
# state_diff  438.30907306998023, center = 71.42226562500001, scrunched = 341.85259412257915, strength = 25.034213322401044, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  455.1305377992893, center = 77.33907470703126, scrunched = 341.85259412257915, strength = 35.93886896967888, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 441.98774696397027, legflexdiff = 82.62627719662129, distance_diff = 148.73889034406352, statewolimbdiff = 136.53916133978677, handlegdiff: 74.08341808349871
# state_diff  526.0810271064826, center = 10.1804931640625, scrunched = 647.4735754947253, strength = 18.42695844769478, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 554.6293177012782, legflexdiff = 118.77193443663748, distance_diff = 100.95331845477247, statewolimbdiff = 37.88247402358609, handlegdiff: 297.0215907862822
# state_diff  560.2780726886076, center = 18.152264404296876, scrunched = 521.6981319105906, strength = 20.427676373720168, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  126.27491341195363, center = 31.318017578125, scrunched = 64.713518356898, strength = 30.24337747693062, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 468.6790911423669, legflexdiff = 109.5698639605946, distance_diff = 136.5932288494392, statewolimbdiff = 37.88247402358609, handlegdiff: 184.6335243087469
# state_diff  73.298835122882, center = 54.588958740234375, scrunched = 156.39095886975394, strength = 12.318917512893677, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  89.98701559930907, center = 54.588958740234375, scrunched = 156.39095886975394, strength = 29.007097989320755, cross = 0.0, separation: -150.0, legmatch: 0.0
# move_diff = 151.17116669010755, legflexdiff = 0.0, distance_diff = 124.17506201031485, statewolimbdiff = 26.996104679792722, handlegdiff: 0.0
# state_diff  611.5904087400718, center = 11.5197509765625, scrunched = 521.6981319105906, strength = 28.372525852918628, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  310.37500729948425, center = 18.052984619140627, scrunched = 254.13379572421454, strength = 38.18822695612907, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 565.4391734359548, legflexdiff = 95.57678390501808, distance_diff = 192.11636303234457, statewolimbdiff = 93.11250218984527, handlegdiff: 184.6335243087469
# ...
# state_diff  538.407354942411, center = 50.945935058593754, scrunched = 175.87151208266593, strength = 11.589907801151277, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  546.0343371783194, center = 42.3702880859375, scrunched = 175.87151208266593, strength = 27.792537009716032, cross = 0.0, separation: 0.0, legmatch: 300.0
# move_diff = 206.803107890248, legflexdiff = 0.0, distance_diff = 42.99280673675215, statewolimbdiff = 163.81030115349583, handlegdiff: 0.0
# state_diff  714.7947009684174, center = 21.51875, scrunched = 628.7505144239991, strength = 14.525436544418334, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  420.2548252515946, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 27.775309324264526, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 889.9865011524812, legflexdiff = 94.9473110216376, distance_diff = 204.23383750064562, statewolimbdiff = 126.07644757547837, handlegdiff: 464.7289050547195
# state_diff  708.4353929929887, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 15.95587706565857, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  420.2548252515946, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 27.775309324264526, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 495.59612844119556, legflexdiff = 50.89808793994377, distance_diff = 152.6942638198313, statewolimbdiff = 126.07644757547837, handlegdiff: 165.92732910594216
# state_diff  415.5675602369461, center = 34.049749755859374, scrunched = 366.5933098726426, strength = 14.924500608444212, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  420.2548252515946, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 27.775309324264526, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 444.6808572390514, legflexdiff = 77.05560464678275, distance_diff = 144.87187705378906, statewolimbdiff = 126.07644757547837, handlegdiff: 96.6769279630012
# state_diff  563.2721942545503, center = 18.447802734375, scrunched = 628.7505144239991, strength = 16.073877096176147, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  229.76424403119188, center = 54.0468994140625, scrunched = 146.39359474110705, strength = 29.323749876022337, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 709.2135848499819, legflexdiff = 94.9473110216376, distance_diff = 80.60809556426715, statewolimbdiff = 68.92927320935756, handlegdiff: 464.7289050547195
# state_diff  435.51278579761134, center = 8.37288818359375, scrunched = 366.5933098726426, strength = 17.740649020671846, cross = 192.80593872070312, separation: -150.0, legmatch: 0.0
# state_diff  314.3806033783112, center = 14.080346679687501, scrunched = 366.5933098726426, strength = 33.706946825981134, cross = 50.0, separation: -150.0, legmatch: 0.0
# move_diff = 178.34055914616857, legflexdiff = 0.0, distance_diff = 84.0263781326752, statewolimbdiff = 94.31418101349335, handlegdiff: 0.0
# state_diff  292.7068470769082, center = 8.37288818359375, scrunched = 366.5933098726426, strength = 17.740649020671846, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  314.3806033783112, center = 14.080346679687501, scrunched = 366.5933098726426, strength = 33.706946825981134, cross = 50.0, separation: -150.0, legmatch: 0.0
# move_diff = 178.34055914616857, legflexdiff = 0.0, distance_diff = 84.0263781326752, statewolimbdiff = 94.31418101349335, handlegdiff: 0.0
# state_diff  795.5736925849852, center = 20.69454345703125, scrunched = 461.16492438411086, strength = 13.714224743843078, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  508.4245013008055, center = 20.69454345703125, scrunched = 461.16492438411086, strength = 26.565033459663393, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 381.8257884583601, legflexdiff = 13.3903879650607, distance_diff = 40.1711638951821, statewolimbdiff = 152.52735039024165, handlegdiff: 175.73688620787559
# state_diff  354.8945130119261, center = 27.435546875, scrunched = 461.16492438411086, strength = 16.294041752815247, cross = 0.0, separation: -150.0, legmatch: 0.0
# state_diff  508.4245013008055, center = 20.69454345703125, scrunched = 461.16492438411086, strength = 26.565033459663393, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 543.6807949543352, legflexdiff = 105.42148692669217, distance_diff = 171.39258372628737, statewolimbdiff = 152.52735039024165, handlegdiff: 114.339373911114
# state_diff  559.6368781265528, center = 47.999243164062506, scrunched = 241.69302036135508, strength = 12.821369361877442, cross = 257.1232452392578, separation: 0.0, legmatch: 0.0
# state_diff  354.1968374308856, center = 33.71614990234375, scrunched = 241.69302036135508, strength = 28.78766716718674, cross = 50.0, separation: 0.0, legmatch: 0.0
# move_diff = 310.3246078516765, legflexdiff = 0.0, distance_diff = 204.06555662241084, statewolimbdiff = 106.25905122926567, handlegdiff: 0.0
# state_diff  568.0650935182509, center = 43.631787109375004, scrunched = 461.16492438411086, strength = 13.268382024765016, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  565.3808298001227, center = 24.9812255859375, scrunched = 461.16492438411086, strength = 29.234679830074313, cross = 50.0, separation: 0.0, legmatch: 0.0
# move_diff = 293.94068871792285, legflexdiff = 0.0, distance_diff = 124.3264397778861, statewolimbdiff = 169.6142489400368, handlegdiff: 0.0
# state_diff  562.1213036189017, center = 37.924328613281254, scrunched = 461.16492438411086, strength = 13.032050621509553, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  565.3808298001227, center = 24.9812255859375, scrunched = 461.16492438411086, strength = 29.234679830074313, cross = 50.0, separation: 0.0, legmatch: 0.0
# move_diff = 212.60705567678895, legflexdiff = 0.0, distance_diff = 42.99280673675215, statewolimbdiff = 169.6142489400368, handlegdiff: 0.0
# state_diff  728.3355987550348, center = 44.04388427734375, scrunched = 628.7505144239991, strength = 12.73526133298874, cross = 192.80593872070312, separation: -150.0, legmatch: 0.0
# state_diff  203.72262988648828, center = 65.22902832031251, scrunched = 98.23982121310644, strength = 25.985134112834928, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 713.8577916890778, legflexdiff = 135.7897321235957, distance_diff = 204.23383750064562, statewolimbdiff = 61.11678896594648, handlegdiff: 312.71743309888996
# state_diff  621.9762968831216, center = 48.411346435546875, scrunched = 366.5933098726426, strength = 14.165701854228972, cross = 192.80593872070312, separation: 0.0, legmatch: 0.0
# state_diff  203.72262988648828, center = 65.22902832031251, scrunched = 98.23982121310644, strength = 25.985134112834928, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 438.00031646579646, legflexdiff = 92.27074282817284, distance_diff = 152.6942638198313, statewolimbdiff = 61.11678896594648, handlegdiff: 131.91852085184578
# state_diff  430.9708354493597, center = 56.57489013671875, scrunched = 168.4556811949232, strength = 13.134325397014619, cross = 192.80593872070312, separation: 0.0, legmatch: 0.0
# state_diff  203.72262988648828, center = 65.22902832031251, scrunched = 98.23982121310644, strength = 25.985134112834928, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 350.4140110281636, legflexdiff = 61.681013649657054, distance_diff = 144.87187705378906, statewolimbdiff = 61.11678896594648, handlegdiff: 82.74433135877102
# state_diff  700.6070058824151, center = 12.740344238281251, scrunched = 628.7505144239991, strength = 16.31020849943161, cross = 192.80593872070312, separation: -150.0, legmatch: 0.0
# state_diff  238.56176317858797, center = 48.33944091796875, scrunched = 146.39359474110705, strength = 29.5600812792778, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 723.2110530462035, legflexdiff = 135.7897321235957, distance_diff = 203.13535887014146, statewolimbdiff = 71.56852895357639, handlegdiff: 312.71743309888996
# state_diff  435.51278579761134, center = 8.37288818359375, scrunched = 366.5933098726426, strength = 17.740649020671846, cross = 192.80593872070312, separation: -150.0, legmatch: 0.0
# state_diff  238.56176317858797, center = 48.33944091796875, scrunched = 146.39359474110705, strength = 29.5600812792778, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 419.8757572982822, legflexdiff = 92.27074282817284, distance_diff = 124.1179646646872, statewolimbdiff = 71.56852895357639, handlegdiff: 131.91852085184578
# state_diff  228.18023085799004, center = 0.20933837890625, scrunched = 168.4556811949232, strength = 16.70927256345749, cross = 192.80593872070312, separation: -150.0, legmatch: 0.0
# state_diff  238.56176317858797, center = 48.33944091796875, scrunched = 146.39359474110705, strength = 29.5600812792778, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 256.1650378571866, legflexdiff = 61.681013649657054, distance_diff = 40.1711638951821, statewolimbdiff = 71.56852895357639, handlegdiff: 82.74433135877102
# state_diff  528.2907714717398, center = 48.33944091796875, scrunched = 146.39359474110705, strength = 19.28908957242966, cross = 14.268646240234375, separation: 0.0, legmatch: 300.0
# state_diff  238.56176317858797, center = 48.33944091796875, scrunched = 146.39359474110705, strength = 29.5600812792778, cross = 14.268646240234375, separation: 0.0, legmatch: 0.0
# move_diff = 378.2952770649382, legflexdiff = 57.1308612420958, distance_diff = 171.39258372628737, statewolimbdiff = 71.56852895357639, handlegdiff: 78.20330314297864
# state_diff  -43.0114868499203, center = 14.152246093750001, scrunched = 26.88579324708744, strength = 15.95047380924225, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  -27.04518904461102, center = 14.152246093750001, scrunched = 26.88579324708744, strength = 31.916771614551543, cross = 50.0, separation: -150.0, legmatch: 0.0
# move_diff = 75.9128214192919, legflexdiff = 0.0, distance_diff = 84.0263781326752, statewolimbdiff = -8.113556713383305, handlegdiff: 0.0
# state_diff  569.2449898622926, center = 34.12825317382813, scrunched = 471.5003222726282, strength = 13.616414415836333, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  252.25329381570197, center = 50.945935058593754, scrunched = 175.87151208266593, strength = 25.43584667444229, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 489.4358885872857, legflexdiff = 82.74530977645814, distance_diff = 124.1179646646872, statewolimbdiff = 75.67598814471059, handlegdiff: 206.8966260014298
# state_diff  519.2449898622926, center = 34.12825317382813, scrunched = 471.5003222726282, strength = 13.616414415836333, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  252.25329381570197, center = 50.945935058593754, scrunched = 175.87151208266593, strength = 25.43584667444229, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 489.4358885872857, legflexdiff = 82.74530977645814, distance_diff = 124.1179646646872, statewolimbdiff = 75.67598814471059, handlegdiff: 206.8966260014298
# state_diff  489.8766910131973, center = 65.22902832031251, scrunched = 98.23982121310644, strength = 12.139195239543916, cross = 14.268646240234375, separation: 0.0, legmatch: 300.0
# state_diff  485.8668840821784, center = 59.52156982421875, scrunched = 98.23982121310644, strength = 28.10549304485321, cross = 0.0, separation: 0.0, legmatch: 300.0
# move_diff = 270.08650500253964, legflexdiff = 0.0, distance_diff = 124.3264397778861, statewolimbdiff = 145.76006522465352, handlegdiff: 0.0
# state_diff  544.3511326347289, center = 56.65338134765625, scrunched = 175.87151208266593, strength = 11.82623920440674, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  546.0343371783194, center = 42.3702880859375, scrunched = 175.87151208266593, strength = 27.792537009716032, cross = 0.0, separation: 0.0, legmatch: 300.0
# move_diff = 247.83667928617103, legflexdiff = 0.0, distance_diff = 84.0263781326752, statewolimbdiff = 163.81030115349583, handlegdiff: 0.0
# state_diff  579.5858701349824, center = 38.33642578125, scrunched = 628.7505144239991, strength = 12.498929929733277, cross = 50.0, separation: -150.0, legmatch: 0.0
# state_diff  183.51019374690463, center = 59.52156982421875, scrunched = 98.23982121310644, strength = 25.748802709579465, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 694.9712102211943, legflexdiff = 94.58115147813622, distance_diff = 80.60809556426715, statewolimbdiff = 55.05305812407139, handlegdiff: 464.7289050547195
# state_diff  664.7947009684174, center = 21.51875, scrunched = 628.7505144239991, strength = 14.525436544418334, cross = 0.0, separation: 0.0, legmatch: 0.0
# state_diff  420.2548252515946, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 27.775309324264526, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 888.5218629784755, legflexdiff = 94.58115147813622, distance_diff = 203.13535887014146, statewolimbdiff = 126.07644757547837, handlegdiff: 464.7289050547195
# state_diff  708.4353929929887, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 15.95587706565857, cross = 0.0, separation: 0.0, legmatch: 300.0
# state_diff  420.2548252515946, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 27.775309324264526, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 457.4943962343368, legflexdiff = 41.37265488822907, distance_diff = 124.1179646646872, statewolimbdiff = 126.07644757547837, handlegdiff: 165.92732910594216
# state_diff  465.5675602369461, center = 34.049749755859374, scrunched = 366.5933098726426, strength = 14.924500608444212, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  420.2548252515946, center = 25.886206054687502, scrunched = 366.5933098726426, strength = 27.775309324264526, cross = 0.0, separation: 0.0, legmatch: 0.0
# move_diff = 305.0799063609088, legflexdiff = 42.1553669272471, distance_diff = 40.1711638951821, statewolimbdiff = 126.07644757547837, handlegdiff: 96.6769279630012
# state_diff  621.9762968831216, center = 48.411346435546875, scrunched = 366.5933098726426, strength = 14.165701854228972, cross = 192.80593872070312, separation: 0.0, legmatch: 0.0
# state_diff  489.429197471634, center = 42.703887939453125, scrunched = 366.5933098726426, strength = 30.131999659538266, cross = 50.0, separation: 0.0, legmatch: 0.0
# move_diff = 230.8551373741654, legflexdiff = 0.0, distance_diff = 84.0263781326752, statewolimbdiff = 146.8287592414902, handlegdiff: 0.0
# state_diff  479.17035816241844, center = 48.411346435546875, scrunched = 366.5933098726426, strength = 14.165701854228972, cross = 50.0, separation: 0.0, legmatch: 0.0
# state_diff  489.429197471634, center = 42.703887939453125, scrunched = 366.5933098726426, strength = 30.131999659538266, cross = 50.0, separation: 0.0, legmatch: 0.0
# move_diff = 230.8551373741654, legflexdiff = 0.0, distance_diff = 84.0263781326752, statewolimbdiff = 146.8287592414902, handlegdiff: 0.0
# TAAAAAAAAAAAAAAKE
# costs: [766.7279842221697, 652.6836113610211, 497.83517298106625, 120.86792035270246, 368.36921926087393, 747.3755310206299, 517.7461373514212, 235.30203763538583, 835.2733955251013, 954.9731995782315, 662.302662869239, 152.94051305910722]
# avg: 542.6997821014124
# total_cost: 9512.39738521695
# - Move your right leg to hold number 12 from the top
# - Move your left leg to hold number 13 from the top
# - Move your left hand to hold number 6 from the top
# - Move your right hand to hold number 6 from the top
# - Move your right leg to hold number 10 from the top
# - Move your left leg to hold number 9 from the top
# - Move your right hand to hold number 3 from the top
# - Move your left hand to hold number 3 from the top
# - Move your right leg to hold number 6 from the top
# - Move your left leg to hold number 5 from the top
# - Move your right hand to hold number 0 from the top
# - Move your left hand to hold number 0 from the top
