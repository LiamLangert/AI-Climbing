# %%
import heapq, random

class PriorityQueue:
    """
      Implements a priority queue data structure. Each inserted item
      has a priority associated with it and the client is usually interested
      in quick retrieval of the lowest-priority item in the queue. This
      data structure allows O(1) access to the lowest-priority item.
    """
    def  __init__(self):
        self.heap = []
        self.count = 0

    def push(self, item, priority):
        entry = (priority, self.count, item)
        heapq.heappush(self.heap, entry)
        self.count += 1

    def pop(self):
        (_, _, item) = heapq.heappop(self.heap)
        return item

    def isEmpty(self):
        return len(self.heap) == 0

    def update(self, item, priority):
        # If item already in priority queue with higher priority, update its priority and rebuild the heap.
        # If item already in priority queue with equal or lower priority, do nothing.
        # If item not in priority queue, do the same thing as self.push.
        for index, (p, c, i) in enumerate(self.heap):
            if i == item:
                if p <= priority:
                    break
                del self.heap[index]
                self.heap.append((priority, c, item))
                heapq.heapify(self.heap)
                break
        else:
            self.push(item, priority)

# %%
class Person:
    def __init__(self, height: int) -> None:
        """
        Represents a person class to get their 
        height: height in inches rounded to nearest whole number
        """
        self.height = height
        self.wingspan = height * 1.06
        self.reach = height * 1.35
        self.leg_length = height * 0.5

# %%
class Hold:
    def __init__(self, x: int, y: int, diff: float, width: float, height: float, angle: int):
        #Coords = top left corner
        self.x = x
        self.y = y
        self.diff = diff
        self.width = width
        self.height = height
        self.angle = angle
    def getCenter(self):
        return (self.coords[0] + self.width/2, self.coords[1] + self.height/2)
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    def __gt__(self, other):
        return self.y > other.y
    def __lt__(self, other):
        return self.y < other.y
    def __ge__(self, other):
        return self.y >= other.y
    def __le__(self, other):
        return self.y <= other.y
    
    def __repr__(self):
        return (f"""Hold: Top left at {self.x}, {self.y}
                Width = {self.width}, Height = {self.height}
                Difficulty = {round(self.diff, 2)}/10, Angle = {self.angle} degrees\n""")

# %%
from enum import Enum

class LimbName(Enum):
    LEFT_HAND = "Left Hand"
    RIGHT_HAND = "Right Hand"
    LEFT_LEG = "Left Leg"
    RIGHT_LEG = "Right Leg"

# %%
class Limb:
    def __init__(self, name: LimbName, strength: int, flexibility: int, hold: Hold):
        self.name, self.strength, self.flexibility, self.hold = name, strength, flexibility, hold
    def __repr__(self):
        return (f"{self.name} at {self.hold}")

# %%
class Route:
    def __init__(self, holds: Hold, start1: Hold, start2: Hold, finish: Hold):
        self.holds = holds
        self.start_hold1 = start1
        self.start_hold2 = start2
        self.finish_hold = finish

# %%
import math
from copy import copy

class State:
    def __init__(self, lf: Limb, rf: Limb, lh: Limb, rh: Limb, person: Person, route: Route):
        self.lf, self.rf, self.lh, self.rh = lf, rf, lh, rh
        self.person = person
        self.moves = []
        self.costs = []
        self.route = route
        self.wall_height_inches = 180 # Represents real height of wall <- need to measure
        self.wall_height_pixels = 3321 #placeholder <- Need to extract from image

    # Not sure where to put this
    def inches_to_pixels(self, inches: int):
        return (self.wall_height_pixels / self.wall_height_inches) * inches

    def __eq__(self, other):
        return ((self.lf.hold == other.lf.hold and self.rf.hold == other.rf.hold 
                and self.rh.hold == other.rh.hold and self.lh.hold == other.lh.hold)
                or (self.lf.hold == other.rf.hold and self.rf.hold == other.lf.hold 
                and self.rh.hold == other.lh.hold and self.lh.hold == other.rh.hold))

    def __repr__(self):
        return f"{self.moves}"

    def getStateSuccessors(self):
        succs = []
        limbs = [self.lf, self.rf, self.lh, self.rh]
        for i in range(len(limbs)):
            neighs = self.getNeighbors(limbs[i])
            for neigh in neighs:
                #print("Hi neighbor")
                new_state = copy(self)
                if i == 0:
                    new_state.lf = Limb(LimbName.LEFT_LEG, 2.5, 8, neigh)
                    action = (self.lf, neigh)
                if i == 1:
                    new_state.rf = Limb(LimbName.RIGHT_LEG, 2.5, 8, neigh)
                    action = (self.rf, neigh)
                if i == 2:
                    new_state.lh = Limb(LimbName.LEFT_HAND, 8, 2, neigh)
                    action = (self.lh, neigh)
                if i == 3:
                    new_state.rh = Limb(LimbName.RIGHT_HAND, 8, 2, neigh)
                    action = (self.rh, neigh)
                succs.append((new_state, action))
        #print(succs)
        return succs

    def getNeighbors(self, limb):
        neighbors = []
        for hold in self.route.holds:
            if not hold == limb.hold:
                if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                    #print("Checking leg neighbors")
                    #print(f"Height diff: {abs(hold.y - limb.hold.y)}")
                    #print(f"Leg length: {self.inches_to_pixels(self.person.leg_length)}")
                    # low_arm is max because pixels go from top to bottom
                    low_arm = max([self.lh.hold.y, self.rh.hold.y])
                    if (0 < limb.hold.y - hold.y < self.inches_to_pixels(self.person.leg_length) and 
                        abs(hold.x - limb.hold.x) < self.inches_to_pixels(self.person.leg_length) and
                        hold.y > low_arm): 
                        neighbors.append(hold)
                elif limb.name in [LimbName.LEFT_HAND, LimbName.RIGHT_HAND]:
                    #print("Checking arm neighbors")
                    #print("HAND TIME 1")
                    upper_leg, lower_leg = sorted([self.lf.hold.y, self.rf.hold.y])
                    if (abs(hold.x - limb.hold.x) < self.inches_to_pixels(self.person.wingspan) and
                        lower_leg - hold.y < self.inches_to_pixels(self.person.height * 0.8) and hold.y < upper_leg and 0 < limb.hold.y - hold.y):
                        #print(hold.y - upper_leg)
                        #print("HAND TIME 2")
                        neighbors.append(hold)
        return neighbors
        
def moveDifficulty(state: State, limb: Limb, next_hold: Hold):
    """
    Evaluates the difficulty of a move
    state: the state that is being evaluated
    """
    distance = math.sqrt(((limb.hold.x - next_hold.x) ** 2) + ((limb.hold.y - next_hold.y) ** 2))
    distance_diff = distance

    new_state = State(copy(state.lf), copy(state.rf), copy(state.lh), copy(state.rh), state.person, state.route)
    new_state_limbs = [new_state.lh, new_state.rh, new_state.lf, new_state.rf]
    for new_state_limb in new_state_limbs:
        if new_state_limb.name == limb.name:
            new_state_limb.hold = None
    state_without_limb_difficulty = 0.3 * stateDifficulty(new_state)
    distance_diff *= 0.1
    move_diff = distance_diff + state_without_limb_difficulty
    #print( distance_diff)
    return move_diff

def stateDifficulty(state: State):
    """
    Finds the difficulty of a certain state
    state: the state that is being evaluated for difficulty
    """
    if state.lh.hold != None and state.rh.hold != None:
        average_hands_x = (state.lh.hold.x + state.rh.hold.x) / 2
        average_hands_y = (state.lh.hold.y + state.rh.hold.y) / 2
    else:
        if state.rh.hold == None:
            average_hands_x = state.lh.hold.x  
            average_hands_y = state.lh.hold.y
        else:
            average_hands_y = state.rh.hold.y
            average_hands_x = state.rh.hold.x
    if state.lf.hold != None and state.rf.hold != None:
        average_legs_x = (state.lf.hold.x + state.rf.hold.x) / 2
        average_legs_y = (state.lf.hold.y + state.rf.hold.y) / 2 
    else:
        if state.rf.hold == None:
            average_legs_x = state.lf.hold.x
            average_legs_y = state.lf.hold.y
        else:
            average_legs_y = state.rf.hold.y
            average_legs_x = state.rf.hold.x

    hands_difference_x = abs(state.rh.hold.x - state.lh.hold.x)if state.lh.hold != None and state.rh.hold != None else 0
    hands_difference_y = abs(state.rh.hold.y - state.lh.hold.y) if state.lh.hold != None and state.rh.hold != None else 0

    legs_difference_x = abs(state.rf.hold.x - state.lf.hold.x) if state.lf.hold != None and state.rf.hold != None else 0
    legs_difference_y = abs(state.lf.hold.y - state.rf.hold.y) if state.lf.hold != None and state.rf.hold != None else 0

    hands_difference_raw_x = state.rh.hold.x - state.lh.hold.x if state.lh.hold != None and state.rh.hold != None else 0
    legs_difference_raw_x = state.rf.hold.x - state.lf.hold.x if state.lf.hold != None and state.rf.hold != None else 0

    leg_match_diff = 0
    if state.lf.hold != None and state.rf.hold != None and state.lf.hold.x - state.rf.hold.x == 0:
        leg_match_diff = 25

    cross_diff = 0
    if hands_difference_raw_x < 0:
        cross_diff += 2 * abs(hands_difference_raw_x / 88)
    if legs_difference_raw_x < 0:
        cross_diff += 100
    if hands_difference_raw_x < 0 and legs_difference_raw_x< 0:
        cross_diff *= 3

    diff = 0
    center_diff = abs(average_hands_x - average_legs_x) ** 2

    target_distance = state.inches_to_pixels(state.person.height * 0.95)
    distance_diff = target_distance - abs(average_legs_y - average_hands_y)
    scrunched_up_diff = (distance_diff ** 2)

    limb_strength_diff = 0
    angle_diff = 0

    # Check each limb and find the strength ratio for the holds
    for limb in [state.lh, state.rh, state.lf, state.rf]:
        if limb.hold != None:
            limb_strength_diff += limb.hold.diff / limb.strength
            if limb.name == LimbName.LEFT_HAND:
                if 315 >= limb.hold.angle >= 270:
                    angle_diff += 2
                elif 90 >= limb.hold.angle or limb.hold.angle > 315:
                    angle_diff += 1
                elif 180 >= limb.hold.angle > 90:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name == LimbName.RIGHT_HAND:
                if 90 >= limb.hold.angle >= 45:
                    angle_diff += 2
                elif 45 >= limb.hold.angle or limb.hold.angle > 270:
                    angle_diff += 1
                elif 270 >= limb.hold.angle > 180:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                if 90 <= limb.hold.angle <= 270:
                    angle_diff += 2
        else:
            limb_strength_diff += 6
    separation_diff = 0
    separation_diff += 0.1 * hands_difference_y
    separation_diff += 0.1 * legs_difference_y


    # If separated too far, make it harder
    if hands_difference_x > state.inches_to_pixels(0.8 * state.person.wingspan):
        separation_diff += 0.5 * hands_difference_x
    separation_diff += 0.5 * legs_difference_y
    if legs_difference_x > state.inches_to_pixels(0.6 * state.person.wingspan):
        separation_diff += 0.5 * legs_difference_x
    
    # Weight all of the different difficulties to balance them out
    center_diff *= .04
    scrunched_up_diff *= 0.05
    angle_diff *= 1
    limb_strength_diff *= 30
    separation_diff *= 0.5
    cross_diff *= 1
    leg_match_diff *=20
    diff += center_diff + scrunched_up_diff + angle_diff + limb_strength_diff + separation_diff + leg_match_diff + cross_diff
    # print(f"center = {center_diff}, scaled = {scrunched_up_diff}, angle = {angle_diff}, strength = {limb_strength_diff}, cross = {cross_diff}")
    return diff

# %%
import numpy as np
from copy import copy


class RouteFinder:
    """
    Class to find the route of a wall
    Takes in a state and gets the person's reach from that
    """
    WALL_HEIGHT = 180
    def __init__(self, state):
        self.state = state
        self.reach = state.person.reach
      
    def getCostValue(self, costs):
        """
        Helper function used to square the costs in the list of costs
        """
        return sum([cost for cost in costs]) + 250 * len(costs)
        
    def uniformCostSearch(self):
        """
        Search function to find the best route 
        """
        explored = []
        frontier = PriorityQueue()
        num = 0
        frontier.push(self.state, 0)
        while not frontier.isEmpty():
            cur_state = frontier.pop()
            explored.append(cur_state)
            if cur_state.lh.hold == self.state.route.finish_hold and cur_state.rh.hold == self.state.route.finish_hold:
                # What every good rock climber says at the top
                print("TAAAAAAAAAAAAAAKE")
                print(cur_state.costs)
                print(self.getCostValue(cur_state.costs))
                return cur_state.moves
            for next_state, action in cur_state.getStateSuccessors():
                if next_state not in explored: 
                    num += 1
                    if num % 500 == 0:
                        print(f"Checking state #{num} with move length {len(cur_state.moves)}")
                    next_state.costs = copy(cur_state.costs)
                    next_state.costs.append(stateDifficulty(next_state) + moveDifficulty(cur_state, action[0], action[1]))
                    next_state.moves = copy(cur_state.moves)
                    next_state.moves.append(action)
                    if next_state in [tup[2] for tup in frontier.heap]:
                        frontier.update(next_state, self.getCostValue(next_state.costs))
                    else:
                        frontier.push(next_state, self.getCostValue(next_state.costs))
        return []

# %%
import get_holds, hold_finder, diff_angle
from get_holds import get_holds_array
import importlib
importlib.reload(get_holds)
importlib.reload(hold_finder)
importlib.reload(diff_angle)

holds = get_holds_array('../images/walls/bluevb.jpg', [210, 10, 30], 30)
holds.sort()
# Out:
# image 1/1 /Users/liam/courses/year4/ai_cs4100/AI-Climbing/src/../images/walls/bluevb.jpg: 1280x544 50 holds, 157.9ms
# Speed: 8.3ms preprocess, 157.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 544)
#
# 0: 64x64 six 0.41, four 0.21, three 0.13, two 0.12, one 0.09, 3.1ms
# Speed: 1.0ms preprocess, 3.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.48, six 0.41, five 0.04, four 0.02, two 0.01, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.70, two 0.15, seven 0.04, eight 0.03, one 0.02, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.43, six 0.25, three 0.19, four 0.11, seven 0.01, 3.4ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.49, two 0.18, seven 0.10, eight 0.07, four 0.04, 3.4ms
# Speed: 1.0ms preprocess, 3.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.47, six 0.14, four 0.10, seven 0.08, one 0.06, 2.2ms
# Speed: 1.1ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.32, downclimb 0.18, two 0.16, eight 0.09, six 0.06, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.89, four 0.07, ten 0.02, five 0.01, nine 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.70, two 0.12, four 0.12, three 0.03, one 0.01, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.29, eight 0.27, downclimb 0.13, six 0.10, nine 0.04, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.20, eight 0.16, six 0.16, two 0.16, nine 0.09, 4.7ms
# Speed: 1.1ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.22, two 0.18, five 0.17, one 0.15, three 0.09, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.87, nine 0.08, eight 0.01, four 0.01, two 0.01, 3.4ms
# Speed: 0.9ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.38, eight 0.19, six 0.11, two 0.09, downclimb 0.06, 2.7ms
# Speed: 1.1ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.37, four 0.18, six 0.13, tag 0.10, five 0.06, 3.3ms
# Speed: 1.0ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 tag 0.98, downclimb 0.01, six 0.00, nine 0.00, seven 0.00, 5.7ms
# Speed: 1.1ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 tag 0.67, six 0.13, seven 0.08, two 0.04, eight 0.03, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.41, two 0.35, seven 0.05, ten 0.05, four 0.03, 2.6ms
# Speed: 0.9ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# 0
#
# 0: 64x64 six 0.41, four 0.21, three 0.13, two 0.12, one 0.09, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.64, five 0.13, ten 0.09, three 0.05, four 0.04, 2.3ms
# Speed: 0.7ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.37, six 0.21, three 0.20, two 0.15, five 0.04, 2.9ms
# Speed: 0.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.59, four 0.19, five 0.09, two 0.05, eight 0.02, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.56, eight 0.16, nine 0.13, ten 0.09, two 0.03, 2.1ms
# Speed: 0.7ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.44, four 0.16, eight 0.12, three 0.10, two 0.06, 3.2ms
# Speed: 0.5ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.34, eight 0.28, four 0.10, nine 0.06, two 0.06, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.48, six 0.41, five 0.04, four 0.02, two 0.01, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.33, ten 0.27, six 0.21, five 0.14, three 0.01, 2.3ms
# Speed: 0.8ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, four 0.29, seven 0.02, two 0.02, eight 0.02, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.30, four 0.18, nine 0.17, five 0.12, ten 0.11, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.68, seven 0.12, ten 0.06, eight 0.04, nine 0.04, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.46, four 0.22, five 0.10, seven 0.09, three 0.05, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.46, three 0.22, two 0.11, nine 0.07, seven 0.04, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.70, two 0.15, seven 0.04, eight 0.03, one 0.02, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.33, ten 0.22, five 0.17, three 0.08, six 0.08, 2.2ms
# Speed: 0.7ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.47, three 0.28, two 0.17, four 0.07, nine 0.01, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.26, two 0.20, seven 0.10, four 0.10, three 0.10, 2.6ms
# Speed: 0.7ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.47, two 0.46, eight 0.02, seven 0.01, three 0.01, 3.2ms
# Speed: 0.8ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.52, two 0.13, four 0.08, eight 0.08, five 0.05, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.46, three 0.25, six 0.11, two 0.11, seven 0.03, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.43, six 0.25, three 0.19, four 0.11, seven 0.01, 6.3ms
# Speed: 0.9ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.46, three 0.13, four 0.10, five 0.10, ten 0.07, 2.9ms
# Speed: 0.6ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.73, four 0.15, two 0.06, five 0.02, ten 0.01, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.26, four 0.21, five 0.14, two 0.11, seven 0.07, 3.5ms
# Speed: 0.8ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.23, four 0.22, six 0.17, ten 0.14, five 0.12, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.45, two 0.26, five 0.10, seven 0.07, six 0.03, 3.7ms
# Speed: 0.9ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.28, six 0.23, two 0.12, five 0.12, seven 0.09, 3.2ms
# Speed: 0.7ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.49, two 0.18, seven 0.10, eight 0.07, four 0.04, 2.3ms
# Speed: 0.9ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.56, ten 0.31, six 0.07, four 0.03, three 0.01, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.29, six 0.25, seven 0.15, two 0.08, eight 0.07, 3.5ms
# Speed: 0.9ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.58, nine 0.16, seven 0.10, three 0.07, five 0.04, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.69, eight 0.15, seven 0.10, two 0.03, downclimb 0.01, 2.3ms
# Speed: 0.9ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.42, five 0.35, seven 0.09, four 0.05, nine 0.02, 3.2ms
# Speed: 0.6ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.38, six 0.21, two 0.16, seven 0.09, three 0.09, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.47, six 0.14, four 0.10, seven 0.08, one 0.06, 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.40, two 0.28, four 0.16, ten 0.08, seven 0.03, 3.7ms
# Speed: 1.0ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, four 0.16, two 0.12, three 0.09, five 0.00, 3.2ms
# Speed: 0.7ms preprocess, 3.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.35, two 0.27, five 0.17, three 0.15, eight 0.02, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, two 0.14, eight 0.13, four 0.06, nine 0.02, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.24, five 0.19, eight 0.12, seven 0.12, three 0.11, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.44, four 0.32, six 0.16, three 0.03, two 0.02, 3.2ms
# Speed: 0.8ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.32, downclimb 0.18, two 0.16, eight 0.09, six 0.06, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.20, nine 0.17, eight 0.16, five 0.12, three 0.11, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.37, two 0.23, three 0.17, eight 0.11, seven 0.07, 2.5ms
# Speed: 0.9ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.58, seven 0.29, four 0.07, eight 0.04, five 0.00, 4.0ms
# Speed: 1.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.37, two 0.31, eight 0.16, ten 0.04, six 0.04, 3.3ms
# Speed: 1.0ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.46, nine 0.34, ten 0.05, three 0.03, four 0.03, 2.9ms
# Speed: 0.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.74, seven 0.08, two 0.08, three 0.05, nine 0.02, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.89, four 0.07, ten 0.02, five 0.01, nine 0.00, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.35, two 0.27, six 0.13, ten 0.10, three 0.04, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.74, six 0.20, seven 0.02, five 0.02, three 0.01, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.87, five 0.04, two 0.04, six 0.02, four 0.01, 2.7ms
# Speed: 3.7ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.98, four 0.01, nine 0.00, two 0.00, ten 0.00, 2.6ms
# Speed: 1.5ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.91, two 0.04, five 0.02, seven 0.01, six 0.01, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.62, two 0.23, three 0.07, four 0.06, tag 0.00, 2.3ms
# Speed: 1.0ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.70, two 0.12, four 0.12, three 0.03, one 0.01, 3.3ms
# Speed: 1.0ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.71, four 0.17, six 0.05, five 0.03, three 0.01, 5.9ms
# Speed: 0.9ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.29, four 0.27, two 0.19, five 0.14, three 0.08, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.72, two 0.10, six 0.07, five 0.06, seven 0.01, 3.4ms
# Speed: 0.9ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.76, eight 0.17, four 0.03, two 0.02, seven 0.02, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, four 0.03, two 0.03, seven 0.03, five 0.02, 3.5ms
# Speed: 0.7ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.52, three 0.24, two 0.12, nine 0.06, tag 0.02, 3.5ms
# Speed: 1.3ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.29, eight 0.27, downclimb 0.13, six 0.10, nine 0.04, 2.7ms
# Speed: 1.1ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.37, four 0.19, ten 0.17, seven 0.11, six 0.05, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.58, three 0.18, six 0.09, seven 0.06, two 0.04, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.65, seven 0.20, nine 0.08, eight 0.03, six 0.02, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.83, eight 0.05, ten 0.04, downclimb 0.02, two 0.02, 3.5ms
# Speed: 1.1ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.30, ten 0.18, six 0.18, five 0.17, seven 0.06, 3.4ms
# Speed: 1.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.44, eight 0.16, seven 0.12, two 0.09, nine 0.05, 5.1ms
# Speed: 0.9ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.20, eight 0.16, six 0.16, two 0.16, nine 0.09, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.25, eight 0.19, four 0.14, nine 0.11, two 0.10, 3.5ms
# Speed: 0.9ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.34, six 0.15, seven 0.12, two 0.12, eight 0.10, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.44, eight 0.25, four 0.11, ten 0.06, two 0.04, 3.9ms
# Speed: 0.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.35, seven 0.28, nine 0.20, six 0.10, four 0.02, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, five 0.06, nine 0.04, eight 0.02, two 0.02, 4.6ms
# Speed: 0.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.41, two 0.22, six 0.17, seven 0.13, nine 0.04, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.22, two 0.18, five 0.17, one 0.15, three 0.09, 4.3ms
# Speed: 1.1ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.33, ten 0.22, five 0.22, seven 0.08, four 0.07, 4.6ms
# Speed: 0.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.67, three 0.14, seven 0.09, four 0.08, two 0.01, 3.5ms
# Speed: 1.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.51, two 0.18, ten 0.12, four 0.08, seven 0.05, 2.3ms
# Speed: 0.9ms preprocess, 2.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.42, six 0.15, nine 0.11, eight 0.09, seven 0.09, 5.1ms
# Speed: 0.9ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.34, seven 0.24, five 0.18, four 0.08, ten 0.07, 13.0ms
# Speed: 0.9ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.79, seven 0.12, two 0.03, six 0.03, three 0.02, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.87, nine 0.08, eight 0.01, four 0.01, two 0.01, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.43, ten 0.16, five 0.11, seven 0.09, two 0.08, 3.7ms
# Speed: 0.9ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.71, two 0.18, three 0.07, four 0.02, nine 0.01, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.49, seven 0.14, ten 0.08, eight 0.07, six 0.05, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.38, six 0.28, eight 0.16, ten 0.07, nine 0.05, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.25, four 0.23, five 0.16, seven 0.09, three 0.09, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.45, two 0.44, four 0.03, seven 0.03, eight 0.02, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.38, eight 0.19, six 0.11, two 0.09, downclimb 0.06, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.57, four 0.15, seven 0.10, eight 0.05, nine 0.05, 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.35, two 0.26, three 0.24, six 0.04, eight 0.04, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.51, seven 0.17, nine 0.15, eight 0.07, ten 0.05, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.83, two 0.06, eight 0.04, downclimb 0.03, ten 0.02, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.86, seven 0.07, ten 0.02, eight 0.02, four 0.01, 3.9ms
# Speed: 1.1ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.52, four 0.32, seven 0.07, two 0.05, nine 0.01, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.37, four 0.18, six 0.13, tag 0.10, five 0.06, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.58, tag 0.14, four 0.06, ten 0.06, eight 0.04, 3.1ms
# Speed: 0.8ms preprocess, 3.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.50, two 0.21, four 0.13, seven 0.09, one 0.02, 3.5ms
# Speed: 1.1ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.38, ten 0.28, four 0.14, two 0.04, seven 0.04, 5.8ms
# Speed: 1.1ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.77, two 0.11, eight 0.04, three 0.03, seven 0.02, 3.3ms
# Speed: 0.8ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.96, ten 0.01, seven 0.01, four 0.01, two 0.00, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.66, four 0.10, six 0.10, seven 0.06, nine 0.03, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.41, two 0.35, seven 0.05, ten 0.05, four 0.03, 3.9ms
# Speed: 1.1ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.37, two 0.36, five 0.11, seven 0.08, three 0.03, 3.4ms
# Speed: 0.9ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.54, six 0.19, two 0.14, four 0.05, five 0.02, 3.8ms
# Speed: 1.0ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.38, four 0.17, seven 0.12, five 0.10, ten 0.07, 3.2ms
# Speed: 0.4ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.74, two 0.12, ten 0.03, five 0.03, four 0.02, 8.3ms
# Speed: 0.7ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.29, four 0.21, three 0.20, five 0.13, seven 0.12, 3.6ms
# Speed: 0.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.20, three 0.18, five 0.16, two 0.16, eight 0.07, 3.3ms
# Speed: 0.7ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running

# %%
def moveToText(action, route):
    output = "- Move your "
    if action[0].name == LimbName.LEFT_LEG:
        output += "left leg "
    elif action[0].name == LimbName.LEFT_HAND:
        output += "left hand "
    elif action[0].name == LimbName.RIGHT_LEG:
        output += "right leg "
    elif action[0].name == LimbName.RIGHT_HAND:
        output += "right hand "
    output += "to hold number "
    output += str(route.holds.index(action[1]))
    output += " from the top"
    return output

# %%
route = Route(holds = holds, start1 = holds[9], start2 = holds[9], finish = holds[0])
lh = Limb(LimbName.LEFT_HAND, 2.5, 8, route.start_hold1)
rh = Limb(LimbName.RIGHT_HAND, 2.5, 8, route.start_hold2)
lf = Limb(LimbName.LEFT_LEG, 8, 5, route.holds[-1])
rf = Limb(LimbName.RIGHT_LEG, 8, 5, route.holds[-2])

#Test people of different heights
ondra = Person(70)
liam = Person(68)
rachel = Person(66)
anna = Person(63)
short = Person(59)
luisa = Person(64)
tall = Person(78)
giga = Person(75)
state1 = State(lf, rf, lh, rh, liam, route)
a_star1 = RouteFinder(state=state1)
results1 = a_star1.uniformCostSearch()

for action in results1:
    print(moveToText(action, route))
# Out:
# Checking state #500 with move length 5
# Checking state #1000 with move length 7
# Checking state #1500 with move length 8
# Checking state #2000 with move length 9
# Checking state #2500 with move length 10
# Checking state #3000 with move length 12
# TAAAAAAAAAAAAAAKE
# [38849.67306723019, 28972.2023372876, 45032.92179001512, 23401.986308781663, 15154.254329680472, 35018.654227445346, 87499.82357608495, 53532.359882351826, 16158.032153745522, 18338.237783148114, 44877.21724196471, 32520.245649841454, 14682.483536071544, 22577.905014773503, 53428.47907818241, 31609.07571700995, 7996.704078369822]
# 573900.2557719841
# - Move your left leg to hold number 13 from the top
# - Move your left hand to hold number 8 from the top
# - Move your right leg to hold number 12 from the top
# - Move your right hand to hold number 7 from the top
# - Move your left hand to hold number 7 from the top
# - Move your right leg to hold number 9 from the top
# - Move your left leg to hold number 9 from the top
# - Move your left hand to hold number 3 from the top
# - Move your right hand to hold number 3 from the top
# - Move your left leg to hold number 8 from the top
# - Move your right leg to hold number 7 from the top
# - Move your right hand to hold number 2 from the top
# - Move your left hand to hold number 2 from the top
# - Move your right leg to hold number 5 from the top
# - Move your left leg to hold number 4 from the top
# - Move your right hand to hold number 0 from the top
# - Move your left hand to hold number 0 from the top

# %%
# Testing cell to check the x,y positions of the holds so we can match the holds to their index

print(len(holds))
for i in range(len(holds)):
    print(f"{i}: {holds[i].x}, {holds[i].y}, {holds[i].diff}")
# Out:
# 16
# 0: 726.4537353515625, 671.9322509765625, 5.423205852508545
# 1: 669.379150390625, 946.1433715820312, 4.7929887771606445
# 2: 583.6227416992188, 1060.96240234375, 3.958439350128174
# 3: 539.9481201171875, 1326.082763671875, 5.150473117828369
# 4: 458.31268310546875, 1601.9052734375, 4.290992736816406
# 5: 939.6136474609375, 1641.247802734375, 6.440840244293213
# 6: 371.77130126953125, 1704.085693359375, 3.4617176055908203
# 7: 761.905029296875, 1854.95458984375, 6.437307834625244
# 8: 313.4748840332031, 1988.7144775390625, 3.498185396194458
# 9: 629.25927734375, 2256.31005859375, 5.954442977905273
# 10: 729.7620849609375, 2354.55517578125, 5.152984142303467
# 11: 446.43450927734375, 2471.044921875, 6.820249080657959
# 12: 858.0624389648438, 2665.64794921875, 6.412820816040039
# 13: 381.1021423339844, 2779.583740234375, 8.287285804748535
# 14: 798.894287109375, 2990.7744140625, 5.912786960601807
# 15: 314.7769775390625, 3097.7529296875, 5.333049297332764
