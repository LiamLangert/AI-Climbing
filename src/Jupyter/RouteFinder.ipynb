# %%
import heapq, random


class PriorityQueue:
    """
    Implements a priority queue data structure. Each inserted item
    has a priority associated with it and the client is usually interested
    in quick retrieval of the lowest-priority item in the queue. This
    data structure allows O(1) access to the lowest-priority item.
    """

    def __init__(self):
        self.heap = []
        self.count = 0

    def push(self, item, priority):
        entry = (priority, self.count, item)
        heapq.heappush(self.heap, entry)
        self.count += 1

    def pop(self):
        (_, _, item) = heapq.heappop(self.heap)
        return item

    def isEmpty(self):
        return len(self.heap) == 0

    def update(self, item, priority):
        # If item already in priority queue with higher priority, update its priority and rebuild the heap.
        # If item already in priority queue with equal or lower priority, do nothing.
        # If item not in priority queue, do the same thing as self.push.
        for index, (p, c, i) in enumerate(self.heap):
            if i == item:
                if p <= priority:
                    break
                del self.heap[index]
                self.heap.append((priority, c, item))
                heapq.heapify(self.heap)
                break
        else:
            self.push(item, priority)

# %%
class Person:
    def __init__(self, height: int) -> None:
        """
        Represents a person class to get their
        height: height in inches rounded to nearest whole number
        """
        self.height = height
        self.wingspan = height * 1.06
        self.reach = height * 1.35
        self.leg_length = height * 0.5

# %%
class Hold:
    """
    Represents a hold in the route
    Has an x,y coordinate, a difficulty rating obtained from the model, a width and height, and an angle obtained from another model.
    """

    def __init__(
        self, x: int, y: int, diff: float, width: float, height: float, angle: int
    ):
        # Coords = middle of the bounding box
        self.x = x
        self.y = y
        self.diff = diff
        self.width = width
        self.height = height
        self.angle = angle

    def get_top_left(self):
        return (self.coords[0] - self.width / 2, self.coords[1] - self.height / 2)

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y

    def __gt__(self, other):
        return self.y > other.y

    def __lt__(self, other):
        return self.y < other.y

    def __ge__(self, other):
        return self.y >= other.y

    def __le__(self, other):
        return self.y <= other.y

    def __repr__(self):
        return f"""Hold: Top left at {self.x}, {self.y}
                Width = {self.width}, Height = {self.height}
                Difficulty = {round(self.diff, 2)}/10, Angle = {self.angle} degrees\n"""

# %%
from enum import Enum


class LimbName(Enum):
    """
    Class for limb names
    """

    LEFT_HAND = "Left Hand"
    RIGHT_HAND = "Right Hand"
    LEFT_LEG = "Left Leg"
    RIGHT_LEG = "Right Leg"

# %%
class Limb:
    def __init__(self, name: LimbName, strength: int, flexibility: int, hold: Hold):
        self.name, self.strength, self.flexibility, self.hold = (
            name,
            strength,
            flexibility,
            hold,
        )

    def __repr__(self):
        return f"{self.name} at {self.hold}"

# %%
class Route:
    def __init__(self, holds: Hold, start1: Hold, start2: Hold, finish: Hold):
        self.holds = holds
        self.start_hold1 = start1
        self.start_hold2 = start2
        self.finish_hold = finish

# %%
# import required module
from PIL import Image


class ImageAttributes:
    def __init__(self, path):
        self.path = path
        img = Image.open(path)
        self.width = img.width
        self.height = img.height

# %%
import math
from copy import copy


class State:
    def __init__(
        self,
        lf: Limb,
        rf: Limb,
        lh: Limb,
        rh: Limb,
        person: Person,
        route: Route,
        image_attributes: ImageAttributes,
    ):
        self.lf, self.rf, self.lh, self.rh = lf, rf, lh, rh
        self.person = person
        self.moves = []
        self.costs = []
        self.route = route
        self.wall_height_inches = (
            180  # Represents real height of wall <- need to measure
        )
        print("img attr", image_attributes, "done with print")
        self.image_attributes = image_attributes
        self.wall_height_pixels = self.image_attributes.height

    # Not sure where to put this
    def inches_to_pixels(self, inches: int):
        return (self.wall_height_pixels / self.wall_height_inches) * inches

    def __eq__(self, other):
        return (
            self.lf.hold == other.lf.hold
            and self.rf.hold == other.rf.hold
            and self.rh.hold == other.rh.hold
            and self.lh.hold == other.lh.hold
        ) or (
            self.lf.hold == other.rf.hold
            and self.rf.hold == other.lf.hold
            and self.rh.hold == other.lh.hold
            and self.lh.hold == other.rh.hold
        )

    def __repr__(self):
        return f"{self.moves}"

    def get_successors(self):
        succs = []
        limbs = [self.lf, self.rf, self.lh, self.rh]
        for i in range(len(limbs)):
            neighs = self.get_neighbors(limbs[i])
            for neigh in neighs:
                # print("Hi neighbor")
                new_state = copy(self)
                if i == 0:
                    new_state.lf = Limb(LimbName.LEFT_LEG, 2.5, 8, neigh)
                    action = (self.lf, neigh)
                if i == 1:
                    new_state.rf = Limb(LimbName.RIGHT_LEG, 2.5, 8, neigh)
                    action = (self.rf, neigh)
                if i == 2:
                    new_state.lh = Limb(LimbName.LEFT_HAND, 8, 2, neigh)
                    action = (self.lh, neigh)
                if i == 3:
                    new_state.rh = Limb(LimbName.RIGHT_HAND, 8, 2, neigh)
                    action = (self.rh, neigh)
                succs.append((new_state, action))
        # print(succs)
        return succs

    def get_neighbors(self, limb):
        neighbors = []
        for hold in self.route.holds:
            if not hold == limb.hold:
                if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                    # print("Checking leg neighbors")
                    # print(f"Height diff: {abs(hold.y - limb.hold.y)}")
                    # print(f"Leg length: {self.inches_to_pixels(self.person.leg_length)}")
                    # low_arm is max because pixels go from top to bottom
                    low_arm = max([self.lh.hold.y, self.rh.hold.y])
                    if (
                        0
                        < limb.hold.y - hold.y
                        < self.inches_to_pixels(self.person.leg_length)
                        and abs(hold.x - limb.hold.x)
                        < self.inches_to_pixels(self.person.leg_length)
                        and hold.y > low_arm
                    ):
                        neighbors.append(hold)
                elif limb.name in [LimbName.LEFT_HAND, LimbName.RIGHT_HAND]:
                    # print("Checking arm neighbors")
                    # print("HAND TIME 1")
                    upper_leg, lower_leg = sorted([self.lf.hold.y, self.rf.hold.y])
                    if (
                        abs(hold.x - limb.hold.x)
                        < self.inches_to_pixels(self.person.wingspan)
                        and lower_leg - hold.y
                        < self.inches_to_pixels(self.person.height * 0.8)
                        and hold.y < upper_leg
                        and 0 < limb.hold.y - hold.y
                    ):
                        # print(hold.y - upper_leg)
                        # print("HAND TIME 2")
                        neighbors.append(hold)
        return neighbors


def move_difficulty(state: State, limb: Limb, next_hold: Hold):
    """
    Evaluates the difficulty of a move
    state: the state that is being evaluated
    """
    distance = math.sqrt(
        ((limb.hold.x - next_hold.x) ** 2) + ((limb.hold.y - next_hold.y) ** 2)
    )
    distance_diff = distance

    new_state = State(
        copy(state.lf),
        copy(state.rf),
        copy(state.lh),
        copy(state.rh),
        state.person,
        state.route,
        state.image_attributes,
    )
    new_state_limbs = [new_state.lh, new_state.rh, new_state.lf, new_state.rf]
    for new_state_limb in new_state_limbs:
        if new_state_limb.name == limb.name:
            new_state_limb.hold = None
    state_without_limb_difficulty = 0.3 * state_difficulty(new_state)
    distance_diff *= 0.1
    move_diff = distance_diff + state_without_limb_difficulty
    return move_diff


def state_difficulty(state: State):
    """
    Finds the difficulty of a certain state
    state: the state that is being evaluated for difficulty
    """
    if state.lh.hold != None and state.rh.hold != None:
        average_hands_x = (state.lh.hold.x + state.rh.hold.x) / 2
        average_hands_y = (state.lh.hold.y + state.rh.hold.y) / 2
    else:
        if state.rh.hold == None:
            average_hands_x = state.lh.hold.x
            average_hands_y = state.lh.hold.y
        else:
            average_hands_y = state.rh.hold.y
            average_hands_x = state.rh.hold.x
    if state.lf.hold != None and state.rf.hold != None:
        average_legs_x = (state.lf.hold.x + state.rf.hold.x) / 2
        average_legs_y = (state.lf.hold.y + state.rf.hold.y) / 2
    else:
        if state.rf.hold == None:
            average_legs_x = state.lf.hold.x
            average_legs_y = state.lf.hold.y
        else:
            average_legs_y = state.rf.hold.y
            average_legs_x = state.rf.hold.x

    hands_difference_x = (
        abs(state.rh.hold.x - state.lh.hold.x)
        if state.lh.hold != None and state.rh.hold != None
        else 0
    )
    hands_difference_y = (
        abs(state.rh.hold.y - state.lh.hold.y)
        if state.lh.hold != None and state.rh.hold != None
        else 0
    )

    legs_difference_x = (
        abs(state.rf.hold.x - state.lf.hold.x)
        if state.lf.hold != None and state.rf.hold != None
        else 0
    )
    legs_difference_y = (
        abs(state.lf.hold.y - state.rf.hold.y)
        if state.lf.hold != None and state.rf.hold != None
        else 0
    )

    hands_difference_raw_x = (
        state.rh.hold.x - state.lh.hold.x
        if state.lh.hold != None and state.rh.hold != None
        else 0
    )
    legs_difference_raw_x = (
        state.rf.hold.x - state.lf.hold.x
        if state.lf.hold != None and state.rf.hold != None
        else 0
    )

    leg_match_diff = 0
    if (
        state.lf.hold != None
        and state.rf.hold != None
        and state.lf.hold.x - state.rf.hold.x == 0
    ):
        leg_match_diff = 25

    cross_diff = 0
    if hands_difference_raw_x < 0:
        cross_diff += 2 * abs(hands_difference_raw_x / 88)
    if legs_difference_raw_x < 0:
        cross_diff += 100
    if hands_difference_raw_x < 0 and legs_difference_raw_x < 0:
        cross_diff *= 3

    diff = 0
    center_diff = abs(average_hands_x - average_legs_x) ** 2

    target_distance = state.inches_to_pixels(state.person.height * 0.95)
    distance_diff = target_distance - abs(average_legs_y - average_hands_y)
    scrunched_up_diff = distance_diff**2

    limb_strength_diff = 0
    angle_diff = 0

    # Check each limb and find the strength ratio for the holds
    for limb in [state.lh, state.rh, state.lf, state.rf]:
        if limb.hold != None:
            limb_strength_diff += limb.hold.diff / limb.strength
            if limb.name == LimbName.LEFT_HAND:
                if 315 >= limb.hold.angle >= 270:
                    angle_diff += 2
                elif 90 >= limb.hold.angle or limb.hold.angle > 315:
                    angle_diff += 1
                elif 180 >= limb.hold.angle > 90:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name == LimbName.RIGHT_HAND:
                if 90 >= limb.hold.angle >= 45:
                    angle_diff += 2
                elif 45 >= limb.hold.angle or limb.hold.angle > 270:
                    angle_diff += 1
                elif 270 >= limb.hold.angle > 180:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                if 90 <= limb.hold.angle <= 270:
                    angle_diff += 2
        else:
            limb_strength_diff += 6
    separation_diff = 0
    separation_diff += 0.1 * hands_difference_y
    separation_diff += 0.1 * legs_difference_y

    # If separated too far, make it harder
    if hands_difference_x > state.inches_to_pixels(0.8 * state.person.wingspan):
        separation_diff += 0.5 * hands_difference_x
    separation_diff += 0.5 * legs_difference_y
    if legs_difference_x > state.inches_to_pixels(0.6 * state.person.wingspan):
        separation_diff += 0.5 * legs_difference_x

    # Weight all of the different difficulties to balance them out
    center_diff *= 0.04
    scrunched_up_diff *= 0.05
    angle_diff *= 1
    limb_strength_diff *= 30
    separation_diff *= 0.5
    cross_diff *= 1
    leg_match_diff *= 20
    diff += (
        center_diff
        + scrunched_up_diff
        + angle_diff
        + limb_strength_diff
        + separation_diff
        + leg_match_diff
        + cross_diff
    )
    # print(f"center = {center_diff}, scaled = {scrunched_up_diff}, angle = {angle_diff}, strength = {limb_strength_diff}, cross = {cross_diff}")
    return diff

# %%
import numpy as np
from copy import copy


class RouteFinder:
    """
    Class to find the route of a wall
    Takes in a state and gets the person's reach from that
    """

    WALL_HEIGHT = 180

    def __init__(self, state):
        self.state = state
        self.reach = state.person.reach

    def get_cost_value(self, costs):
        """
        Helper function used to square the costs in the list of costs
        """
        return sum([cost for cost in costs]) + 250 * len(costs)

    def uniform_cost_search(self):
        """
        Search function to find the best route
        """
        explored = []
        frontier = PriorityQueue()
        num = 0
        frontier.push(self.state, 0)
        while not frontier.isEmpty():
            cur_state = frontier.pop()
            explored.append(cur_state)
            if (
                cur_state.lh.hold == self.state.route.finish_hold
                and cur_state.rh.hold == self.state.route.finish_hold
            ):
                # What every good rock climber says at the top
                print("TAAAAAAAAAAAAAAKE")
                print(cur_state.costs)
                print(self.get_cost_value(cur_state.costs))
                return cur_state.moves
            for next_state, action in cur_state.get_successors():
                if next_state not in explored:
                    num += 1
                    if num % 500 == 0:
                        print(
                            f"Checking state #{num} with move length {len(cur_state.moves)}"
                        )
                    next_state.costs = copy(cur_state.costs)
                    next_state.costs.append(
                        state_difficulty(next_state)
                        + move_difficulty(cur_state, action[0], action[1])
                    )
                    next_state.moves = copy(cur_state.moves)
                    next_state.moves.append(action)
                    if next_state in [tup[2] for tup in frontier.heap]:
                        frontier.update(
                            next_state, self.get_cost_value(next_state.costs)
                        )
                    else:
                        frontier.push(next_state, self.get_cost_value(next_state.costs))
        return []

# %%
import get_holds, hold_finder, diff_angle
from get_holds import get_holds_array
import importlib

importlib.reload(get_holds)
importlib.reload(hold_finder)
importlib.reload(diff_angle)

image_path = "../images/walls/redroute1.jpg"

holds = get_holds_array(image_path, [0, 20, 30], 10)
holds.sort()

image = ImageAttributes(path=image_path)
print("height", image.height)
# Out:
# image 1/1 /Users/liam/courses/year4/ai_cs4100/AI-Climbing/src/../images/walls/redroute1.jpg: 1280x672 47 holds, 205.8ms
# Speed: 12.1ms preprocess, 205.8ms inference, 1.1ms postprocess per image at shape (1, 3, 1280, 672)
#
# 0: 64x64 three 0.49, two 0.36, seven 0.04, four 0.03, six 0.03, 5.4ms
# Speed: 2.0ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.76, three 0.12, four 0.07, two 0.04, seven 0.01, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 three 0.39, two 0.19, eight 0.19, four 0.09, seven 0.06, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.36, ten 0.32, two 0.11, seven 0.06, eight 0.05, 4.4ms
# Speed: 1.1ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.31, eight 0.27, one 0.23, seven 0.18, downclimb 0.00, 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.54, four 0.42, eight 0.02, seven 0.01, six 0.00, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.59, seven 0.28, five 0.04, four 0.03, three 0.02, 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.81, four 0.11, eight 0.02, three 0.02, six 0.02, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.27, one 0.14, five 0.13, eight 0.12, downclimb 0.10, 3.7ms
# Speed: 1.4ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 eight 0.30, four 0.21, six 0.15, downclimb 0.11, seven 0.08, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.95, seven 0.02, five 0.01, six 0.01, three 0.01, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.43, four 0.20, eight 0.11, one 0.08, seven 0.08, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.69, five 0.10, downclimb 0.08, seven 0.07, two 0.01, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.88, seven 0.06, five 0.02, eight 0.02, six 0.01, 5.9ms
# Speed: 1.0ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.93, seven 0.02, eight 0.01, three 0.01, six 0.01, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 downclimb 0.73, six 0.09, seven 0.06, two 0.05, eight 0.03, 8.5ms
# Speed: 1.2ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.99, two 0.01, eight 0.00, downclimb 0.00, three 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.61, eight 0.20, one 0.04, seven 0.03, four 0.03, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# 2
#
# 0: 64x64 three 0.49, two 0.36, seven 0.04, four 0.03, six 0.03, 4.7ms
# Speed: 1.6ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.48, ten 0.36, five 0.08, two 0.03, six 0.02, 9.4ms
# Speed: 0.9ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.40, two 0.31, one 0.13, four 0.07, three 0.05, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.57, five 0.26, seven 0.13, two 0.02, nine 0.01, 3.7ms
# Speed: 0.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.42, six 0.29, eight 0.15, two 0.05, one 0.05, 7.5ms
# Speed: 0.8ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.67, ten 0.12, five 0.12, eight 0.02, two 0.02, 3.7ms
# Speed: 0.8ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.57, one 0.19, six 0.09, four 0.08, two 0.04, 3.6ms
# Speed: 1.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.76, three 0.12, four 0.07, two 0.04, seven 0.01, 3.6ms
# Speed: 0.9ms preprocess, 3.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.81, ten 0.08, seven 0.04, tag 0.02, four 0.02, 3.8ms
# Speed: 1.0ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.44, one 0.33, seven 0.14, six 0.03, four 0.03, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.94, ten 0.02, seven 0.02, eight 0.00, one 0.00, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.80, seven 0.06, eight 0.03, four 0.03, six 0.02, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.58, tag 0.20, ten 0.06, five 0.04, nine 0.03, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.67, eight 0.18, six 0.10, seven 0.03, four 0.01, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.39, two 0.19, eight 0.19, four 0.09, seven 0.06, 4.8ms
# Speed: 0.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.40, seven 0.22, five 0.11, eight 0.07, tag 0.06, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.25, one 0.23, seven 0.22, four 0.13, six 0.04, 2.5ms
# Speed: 1.3ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.98, five 0.01, tag 0.00, nine 0.00, three 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.51, five 0.18, nine 0.12, seven 0.09, eight 0.03, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.45, ten 0.44, three 0.02, nine 0.02, tag 0.01, 76.4ms
# Speed: 0.9ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.90, six 0.06, four 0.01, five 0.01, seven 0.01, 13.2ms
# Speed: 1.1ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.36, ten 0.32, two 0.11, seven 0.06, eight 0.05, 3.4ms
# Speed: 0.6ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.99, ten 0.01, tag 0.00, two 0.00, three 0.00, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.50, seven 0.32, eight 0.11, tag 0.03, two 0.01, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.65, ten 0.35, tag 0.00, two 0.00, four 0.00, 3.8ms
# Speed: 1.4ms preprocess, 3.8ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.41, seven 0.36, five 0.21, two 0.01, tag 0.01, 3.0ms
# Speed: 0.6ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.98, seven 0.01, ten 0.00, four 0.00, tag 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.29, four 0.28, seven 0.25, three 0.08, eight 0.04, 2.4ms
# Speed: 0.6ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.31, eight 0.27, one 0.23, seven 0.18, downclimb 0.00, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.90, seven 0.04, four 0.02, nine 0.02, three 0.01, 3.5ms
# Speed: 1.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.68, one 0.14, nine 0.07, two 0.04, four 0.03, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.35, ten 0.15, eight 0.12, five 0.12, nine 0.10, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.88, two 0.05, four 0.05, eight 0.01, six 0.01, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.56, ten 0.23, nine 0.08, four 0.05, seven 0.04, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.77, three 0.08, one 0.06, tag 0.04, four 0.03, 3.5ms
# Speed: 1.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.54, four 0.42, eight 0.02, seven 0.01, six 0.00, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.32, ten 0.24, tag 0.15, four 0.07, five 0.07, 3.8ms
# Speed: 1.0ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.74, four 0.21, two 0.01, three 0.01, eight 0.01, 3.7ms
# Speed: 0.6ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.53, seven 0.38, two 0.02, four 0.02, ten 0.01, 3.4ms
# Speed: 0.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.81, four 0.15, eight 0.01, two 0.01, one 0.00, 3.4ms
# Speed: 2.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.46, five 0.23, tag 0.10, seven 0.09, four 0.03, 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 four 0.67, one 0.29, seven 0.01, eight 0.01, two 0.00, 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.59, seven 0.28, five 0.04, four 0.03, three 0.02, 3.2ms
# Speed: 1.4ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.77, ten 0.06, eight 0.03, five 0.03, nine 0.03, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.41, seven 0.41, eight 0.04, one 0.03, four 0.03, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.59, ten 0.19, five 0.07, four 0.05, nine 0.03, 4.6ms
# Speed: 2.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.46, two 0.28, four 0.12, three 0.06, six 0.03, 14.0ms
# Speed: 0.4ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.51, five 0.37, ten 0.04, four 0.02, nine 0.02, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.60, six 0.14, one 0.11, tag 0.03, four 0.03, 3.7ms
# Speed: 2.2ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 one 0.81, four 0.11, eight 0.02, three 0.02, six 0.02, 9.8ms
# Speed: 4.1ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.92, five 0.06, two 0.01, four 0.00, seven 0.00, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.38, one 0.16, four 0.15, nine 0.07, three 0.04, 3.8ms
# Speed: 1.1ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.55, ten 0.25, seven 0.10, two 0.04, four 0.02, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.29, one 0.28, eight 0.16, seven 0.12, six 0.04, 5.2ms
# Speed: 0.8ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.72, five 0.17, four 0.04, seven 0.03, nine 0.02, 2.1ms
# Speed: 1.1ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.48, six 0.17, tag 0.12, one 0.06, nine 0.05, 3.6ms
# Speed: 1.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.27, one 0.14, five 0.13, eight 0.12, downclimb 0.10, 3.5ms
# Speed: 1.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.65, five 0.33, tag 0.01, seven 0.01, two 0.00, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.35, ten 0.18, five 0.17, seven 0.16, six 0.06, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.53, ten 0.43, seven 0.02, tag 0.00, six 0.00, 5.2ms
# Speed: 0.8ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.60, ten 0.24, five 0.09, two 0.05, three 0.01, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.58, five 0.38, seven 0.02, two 0.00, tag 0.00, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.34, tag 0.13, one 0.11, six 0.10, ten 0.09, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.30, four 0.21, six 0.15, downclimb 0.11, seven 0.08, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.97, seven 0.01, four 0.01, ten 0.00, nine 0.00, 3.4ms
# Speed: 1.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.98, seven 0.01, bolt 0.01, five 0.00, ten 0.00, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.60, seven 0.20, ten 0.13, four 0.02, eight 0.01, 7.4ms
# Speed: 0.8ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.52, eight 0.23, seven 0.18, ten 0.04, two 0.02, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.47, four 0.13, ten 0.13, seven 0.09, three 0.06, 5.4ms
# Speed: 0.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 two 0.77, four 0.10, seven 0.09, six 0.03, eight 0.00, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.95, seven 0.02, five 0.01, six 0.01, three 0.01, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.68, five 0.31, seven 0.00, nine 0.00, tag 0.00, 3.3ms
# Speed: 0.8ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.48, five 0.38, two 0.05, three 0.02, seven 0.02, 3.7ms
# Speed: 1.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.50, five 0.29, seven 0.04, eight 0.03, three 0.03, 3.9ms
# Speed: 1.9ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.55, seven 0.19, six 0.08, eight 0.05, five 0.03, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.93, five 0.05, seven 0.01, three 0.00, eight 0.00, 2.6ms
# Speed: 2.4ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.44, two 0.34, five 0.08, seven 0.03, three 0.03, 7.9ms
# Speed: 0.9ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.43, four 0.20, eight 0.11, one 0.08, seven 0.08, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.96, seven 0.02, four 0.01, eight 0.00, ten 0.00, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.68, six 0.23, two 0.05, one 0.02, four 0.01, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.73, eight 0.16, five 0.05, four 0.04, two 0.01, 3.1ms
# Speed: 0.6ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 eight 0.50, six 0.29, seven 0.16, one 0.03, four 0.01, 2.4ms
# Speed: 0.8ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.73, seven 0.12, four 0.08, three 0.02, one 0.02, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.43, seven 0.34, tag 0.07, one 0.05, four 0.05, 2.6ms
# Speed: 0.7ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.69, five 0.10, downclimb 0.08, seven 0.07, two 0.01, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, five 0.14, seven 0.02, three 0.00, downclimb 0.00, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, five 0.13, four 0.01, two 0.01, three 0.01, 3.1ms
# Speed: 0.8ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.37, five 0.28, seven 0.17, four 0.05, eight 0.05, 4.1ms
# Speed: 2.3ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.57, seven 0.28, downclimb 0.08, eight 0.04, five 0.02, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.62, five 0.34, seven 0.02, six 0.00, nine 0.00, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.98, five 0.01, two 0.00, three 0.00, eight 0.00, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.88, seven 0.06, five 0.02, eight 0.02, six 0.01, 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.97, five 0.02, three 0.00, seven 0.00, six 0.00, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.36, three 0.14, eight 0.12, five 0.10, two 0.06, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.92, five 0.05, tag 0.01, two 0.00, eight 0.00, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.70, eight 0.12, nine 0.08, tag 0.02, three 0.02, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.78, seven 0.14, five 0.04, eight 0.01, three 0.01, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 nine 0.46, seven 0.45, six 0.05, five 0.04, tag 0.01, 9.1ms
# Speed: 1.4ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.93, seven 0.02, eight 0.01, three 0.01, six 0.01, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.88, five 0.08, eight 0.01, tag 0.01, three 0.01, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 three 0.28, eight 0.27, nine 0.22, one 0.13, five 0.04, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.97, five 0.03, tag 0.00, two 0.00, seven 0.00, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.83, seven 0.09, five 0.05, nine 0.01, six 0.01, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.97, five 0.03, tag 0.00, two 0.00, three 0.00, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.77, seven 0.13, nine 0.04, six 0.03, five 0.01, 4.7ms
# Speed: 1.1ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.99, two 0.01, eight 0.00, downclimb 0.00, three 0.00, 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.41, seven 0.37, ten 0.18, eight 0.01, nine 0.01, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.88, seven 0.10, ten 0.01, tag 0.00, two 0.00, 7.8ms
# Speed: 0.9ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.56, seven 0.21, five 0.14, eight 0.03, tag 0.02, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.96, two 0.03, eight 0.00, ten 0.00, downclimb 0.00, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.76, five 0.12, ten 0.07, four 0.02, one 0.01, 3.5ms
# Speed: 0.8ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.68, five 0.11, tag 0.09, two 0.08, six 0.02, 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.61, eight 0.20, one 0.04, seven 0.03, four 0.03, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.53, ten 0.25, seven 0.14, four 0.05, six 0.02, 6.1ms
# Speed: 0.8ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.41, six 0.38, four 0.06, tag 0.05, two 0.05, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 ten 0.54, five 0.35, seven 0.08, eight 0.01, two 0.01, 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 seven 0.53, six 0.23, eight 0.06, downclimb 0.05, two 0.04, 4.4ms
# Speed: 1.1ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 five 0.61, seven 0.19, ten 0.16, four 0.02, nine 0.00, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# running
#
# 0: 64x64 six 0.49, two 0.43, seven 0.05, three 0.01, four 0.01, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# running
# height 3297

# %%
def move_to_text(action, route):
    output = "- Move your "
    if action[0].name == LimbName.LEFT_LEG:
        output += "left leg "
    elif action[0].name == LimbName.LEFT_HAND:
        output += "left hand "
    elif action[0].name == LimbName.RIGHT_LEG:
        output += "right leg "
    elif action[0].name == LimbName.RIGHT_HAND:
        output += "right hand "
    output += "to hold number "
    output += str(route.holds.index(action[1]))
    output += " from the top"
    return output

# %%
route = Route(holds=holds, start1=holds[9], start2=holds[9], finish=holds[0])
lh = Limb(LimbName.LEFT_HAND, 2.5, 8, route.start_hold1)
rh = Limb(LimbName.RIGHT_HAND, 2.5, 8, route.start_hold2)
lf = Limb(LimbName.LEFT_LEG, 8, 5, route.holds[-1])
rf = Limb(LimbName.RIGHT_LEG, 8, 5, route.holds[-2])


# Test people of different heights
ondra = Person(70)
liam = Person(68)
rachel = Person(66)
anna = Person(63)
short = Person(59)
luisa = Person(64)
tall = Person(78)
giga = Person(75)
state1 = State(lf, rf, lh, rh, liam, route, image)
a_star1 = RouteFinder(state=state1)
results1 = a_star1.uniform_cost_search()

for action in results1:
    print(move_to_text(action, route))
# Out:
# img attr <__main__.ImageAttributes object at 0x14bac9ed0> done with print
# img attr 3297 done with print
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 19
#      17 state1 = State(lf, rf, lh, rh, liam, route, image)
#      18 a_star1 = RouteFinder(state=state1)
# ---> 19 results1 = a_star1.uniform_cost_search()
#      21 for action in results1:
#      22     print(move_to_text(action, route))
#
# Cell In[31], line 53, in RouteFinder.uniform_cost_search(self)
#      47     print(
#      48         f"Checking state #{num} with move length {len(cur_state.moves)}"
#      49     )
#      50 next_state.costs = copy(cur_state.costs)
#      51 next_state.costs.append(
#      52     state_difficulty(next_state)
# ---> 53     + move_difficulty(cur_state, action[0], action[1])
#      54 )
#      55 next_state.moves = copy(cur_state.moves)
#      56 next_state.moves.append(action)
#
# Cell In[49], line 118, in move_difficulty(state, limb, next_hold)
#     113 distance = math.sqrt(
#     114     ((limb.hold.x - next_hold.x) ** 2) + ((limb.hold.y - next_hold.y) ** 2)
#     115 )
#     116 distance_diff = distance
# --> 118 new_state = State(
#     119     copy(state.lf),
#     120     copy(state.rf),
#     121     copy(state.lh),
#     122     copy(state.rh),
#     123     state.person,
#     124     state.route,
#     125     state.wall_height_pixels,
#     126 )
#     127 new_state_limbs = [new_state.lh, new_state.rh, new_state.lf, new_state.rf]
#     128 for new_state_limb in new_state_limbs:
#
# Cell In[49], line 25, in State.__init__(self, lf, rf, lh, rh, person, route, image_attributes)
#      21 self.wall_height_inches = (
#      22     180  # Represents real height of wall <- need to measure
#      23 )
#      24 print("img attr", image_attributes, 'done with print')
# ---> 25 self.wall_height_pixels = image_attributes.height
#
# AttributeError: 'int' object has no attribute 'height'

# %%
# Testing cell to check the x,y positions of the holds so we can match the holds to their index

print(len(holds))
for i in range(len(holds)):
    print(f"{i}: {holds[i].x}, {holds[i].y}, {holds[i].diff}")
# Out:
# 16
# 0: 726.4537353515625, 671.9322509765625, 5.423205852508545
# 1: 669.379150390625, 946.1433715820312, 4.7929887771606445
# 2: 583.6227416992188, 1060.96240234375, 3.958439350128174
# 3: 539.9481201171875, 1326.082763671875, 5.150473117828369
# 4: 458.31268310546875, 1601.9052734375, 4.290992736816406
# 5: 939.6136474609375, 1641.247802734375, 6.440840244293213
# 6: 371.77130126953125, 1704.085693359375, 3.4617176055908203
# 7: 761.905029296875, 1854.95458984375, 6.437307834625244
# 8: 313.4748840332031, 1988.7144775390625, 3.498185396194458
# 9: 629.25927734375, 2256.31005859375, 5.954442977905273
# 10: 729.7620849609375, 2354.55517578125, 5.152984142303467
# 11: 446.43450927734375, 2471.044921875, 6.820249080657959
# 12: 858.0624389648438, 2665.64794921875, 6.412820816040039
# 13: 381.1021423339844, 2779.583740234375, 8.287285804748535
# 14: 798.894287109375, 2990.7744140625, 5.912786960601807
# 15: 314.7769775390625, 3097.7529296875, 5.333049297332764
