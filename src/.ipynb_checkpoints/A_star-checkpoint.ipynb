# %%
import heapq, random

class PriorityQueue:
    """
      Implements a priority queue data structure. Each inserted item
      has a priority associated with it and the client is usually interested
      in quick retrieval of the lowest-priority item in the queue. This
      data structure allows O(1) access to the lowest-priority item.
    """
    def  __init__(self):
        self.heap = []
        self.count = 0

    def push(self, item, priority):
        entry = (priority, self.count, item)
        heapq.heappush(self.heap, entry)
        self.count += 1

    def pop(self):
        (_, _, item) = heapq.heappop(self.heap)
        return item

    def isEmpty(self):
        return len(self.heap) == 0

    def update(self, item, priority):
        # If item already in priority queue with higher priority, update its priority and rebuild the heap.
        # If item already in priority queue with equal or lower priority, do nothing.
        # If item not in priority queue, do the same thing as self.push.
        for index, (p, c, i) in enumerate(self.heap):
            if i == item:
                if p <= priority:
                    break
                del self.heap[index]
                self.heap.append((priority, c, item))
                heapq.heapify(self.heap)
                break
        else:
            self.push(item, priority)

# %%
class Person:
    def __init__(self, height: int) -> None:
        """
        height: height in inches rounded to nearest whole number
        """
        self.height = height
        self.wingspan = height * 1.06
        self.reach = height * 1.35
        self.leg_length = height * 0.5

# %%
class Hold:
    def __init__(self, x: int, y: int, diff: float, width: float, height: float, angle: int):
        #Coords = top left corner
        self.x = x
        self.y = y
        self.diff = diff
        self.width = width
        self.height = height
        self.angle = angle
    def getCenter(self):
        return (self.coords[0] + self.width/2, self.coords[1] + self.height/2)
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    def __gt__(self, other):
        return self.y > other.y
    def __lt__(self, other):
        return self.y < other.y
    def __ge__(self, other):
        return self.y >= other.y
    def __le__(self, other):
        return self.y <= other.y
    
    def __repr__(self):
        return (f"""Hold: Top left at {self.x}, {self.y}
                Width = {self.width}, Height = {self.height}
                Difficulty = {round(self.diff, 2)}/10, Angle = {self.angle} degrees\n""")

# %%
from enum import Enum

class LimbName(Enum):
    LEFT_HAND = "Left Hand"
    RIGHT_HAND = "Right Hand"
    LEFT_LEG = "Left Leg"
    RIGHT_LEG = "Right Leg"

# %%
class Limb:
    def __init__(self, name: LimbName, strength: int, flexibility: int, hold: Hold):
        self.name, self.strength, self.flexibility, self.hold = name, strength, flexibility, hold
    def __repr__(self):
        return (f"{self.name} at {self.hold}")

# %%
class Route:
    def __init__(self, holds: Hold, start1: Hold, start2: Hold, finish: Hold):
        self.holds = holds
        self.start_hold1 = start1
        self.start_hold2 = start2
        self.finish_hold = finish

# %%
import math
from copy import copy

class State:
    def __init__(self, lf: Limb, rf: Limb, lh: Limb, rh: Limb, person: Person, route: Route):
        self.lf, self.rf, self.lh, self.rh = lf, rf, lh, rh
        self.person = person
        self.moves = []
        self.costs = []
        self.route = route
        self.wall_height_inches = 180 # Represents real height of wall <- need to measure
        self.wall_height_pixels = 3321 #placeholder <- Need to extract from image

    # Not sure where to put this
    def inches_to_pixels(self, inches: int):
        return (self.wall_height_pixels / self.wall_height_inches) * inches

    def __eq__(self, other):
        return (self.lf.hold == other.lf.hold and self.rf.hold == other.rf.hold 
                and self.rh.hold == other.rh.hold and self.lh.hold == other.lh.hold)

    def __repr__(self):
        return f"{self.moves}"

    def getStateSuccessors(self):
        succs = []
        limbs = [self.lf, self.rf, self.lh, self.rh]
        for i in range(len(limbs)):
            neighs = self.getNeighbors(limbs[i])
            for neigh in neighs:
                #print("Hi neighbor")
                new_state = copy(self)
                if i == 0:
                    new_state.lf = Limb(LimbName.LEFT_LEG, 2.5, 8, neigh)
                    action = (state.lf, neigh)
                if i == 1:
                    new_state.rf = Limb(LimbName.RIGHT_LEG, 2.5, 8, neigh)
                    action = (state.rf, neigh)
                if i == 2:
                    new_state.lh = Limb(LimbName.LEFT_HAND, 8, 2, neigh)
                    action = (state.lh, neigh)
                if i == 3:
                    new_state.rh = Limb(LimbName.RIGHT_HAND, 8, 2, neigh)
                    action = (state.rh, neigh)
                succs.append((new_state, action))
        #print(succs)
        return succs

    def getNeighbors(self, limb):
        neighbors = []
        for hold in self.route.holds:
            if not hold == limb.hold:
                if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                    #print("Checking leg neighbors")
                    #print(f"Height diff: {abs(hold.y - limb.hold.y)}")
                    #print(f"Leg length: {self.inches_to_pixels(self.person.leg_length)}")
                    if (abs(hold.y - limb.hold.y) < self.inches_to_pixels(self.person.leg_length) and 
                        abs(hold.x - limb.hold.x) < self.inches_to_pixels(self.person.leg_length)): 
                        neighbors.append(hold)
                elif limb.name in [LimbName.LEFT_HAND, LimbName.RIGHT_HAND]:
                    #print("Checking arm neighbors")
                    #print("HAND TIME 1")
                    lower_leg, upper_leg = sorted([self.lf.hold.y, self.rf.hold.y])
                    if (abs(hold.x - limb.hold.x) < self.inches_to_pixels(self.person.wingspan) and
                        upper_leg - hold.y < self.inches_to_pixels(self.person.reach) and hold.y < upper_leg):
                        #print(hold.y - upper_leg)
                        #print("HAND TIME 2")
                        neighbors.append(hold)
        return neighbors
        
def moveDifficulty(state: State, limb: Limb, next_hold: Hold):
    distance = math.sqrt(((limb.hold.x - next_hold.x) ** 2) + ((limb.hold.y - next_hold.y) ** 2))
    distance_diff = 0.5 * distance

    lh, rh, lf, rf, person = state.lh, state.rh, state.lf, state.rf, state.person
    new_state_limbs = [lh, rh, lf, rf]
    for new_state_limb in new_state_limbs:
        if new_state_limb.name == limb.name:
            new_state_limb.hold = None
    new_state = State(lh=lh, rh=rh, lf=lf, rf=rf, person=person)
    state_without_limb_difficulty = 0.5 * state_difficulty(new_state)
    move_diff = distance_diff + state_without_limb_difficulty
    
    return move_diff

def stateDifficulty(state: State):
    average_hands_x = (state.lh.hold.x + state.rh.hold.x) / 2 if state.lh.hold != None and state.rh.hold != None else state.lh.hold.x if state.rh.hold == None else state.rh.hold.x
    average_legs_x = (state.lf.hold.x + state.rf.hold.x) / 2 if state.lf.hold != None and state.rf.hold != None else state.lf.hold.x if state.rf.hold == None else state.rf.hold.x
    average_hands_y = (state.lh.hold.y + state.rh.hold.y) / 2 if state.lh.hold != None and state.rh.hold != None else state.lh.hold.y if state.rh.hold == None else state.rh.hold.y
    average_legs_y = (state.lf.hold.y + state.rf.hold.y) / 2 if state.lh.hold != None and state.rh.hold != None else state.lf.hold.y if state.rh.hold == None else state.rf.hold.y

    hands_difference_x = abs(state.lh.hold.x - state.rh.hold.x) if state.lh.hold != None and state.rh.hold != None else 0
    hands_difference_y = abs(state.lh.hold.y - state.rh.hold.y) if state.lh.hold != None and state.rh.hold != None else 0

    legs_difference_x = abs(state.lf.hold.x - state.rf.hold.x) if state.lf.hold != None and state.rf.hold != None else 0
    legs_difference_y = abs(state.lf.hold.y - state.rf.hold.y) if state.lf.hold != None and state.rf.hold != None else 0

    diff = 0
    center_diff = 0.5*abs(average_hands_x - average_legs_x)

    target_distance = state.inches_to_pixels(state.inches_to_pixels(state.person.height * 0.8))
    scaling_factor = 0.1
    distance_diff = abs(average_legs_y - average_hands_y) + target_distance

    raw_difficulty_score = (scaling_factor * (distance_diff ** 2))

    # Scales the difficulty score linearly between 1 and 10
    scaled_difficulty_score = 1 + 9 * ((raw_difficulty_score) / (1 + scaling_factor * target_distance ** 2))

    limb_strength_diff = 0
    angle_diff = 0
    for limb in [state.lh, state.rh, state.lf, state.rf]:
        if limb.hold != None:
            limb_strength_diff += limb.hold.diff / limb.strength
            if limb.name == LimbName.LEFT_HAND:
                if 315 >= limb.hold.angle >= 270:
                    angle_diff += 2
                elif 90 >= limb.hold.angle or limb.hold.angle > 315:
                    angle_diff += 1
                elif 180 >= limb.hold.angle > 90:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name == LimbName.RIGHT_HAND:
                if 90 >= limb.hold.angle >= 45:
                    angle_diff += 2
                elif 45 >= limb.hold.angle or limb.hold.angle > 270:
                    angle_diff += 1
                elif 270 >= limb.hold.angle > 180:
                    angle_diff += 2.5
                else:
                    angle_diff += 3
            if limb.name in [LimbName.LEFT_LEG, LimbName.RIGHT_LEG]:
                if 90 <= limb.hold.angle <= 270:
                    angle_diff += 2
        else:
            limb_strength_diff += 6
    if hands_difference_y > state.inches_to_pixels(state.inches_to_pixels(0.6 * state.person.wingspan)): 
        diff += 0.5 * hands_difference_y 
    if hands_difference_x > state.inches_to_pixels(state.inches_to_pixels(0.8 * state.person.wingspan)):
        diff += 0.5 * hands_difference_x
    if legs_difference_y > state.inches_to_pixels(state.inches_to_pixels(0.25 * state.person.height)):
        diff += 0.5 * legs_difference_y
    if legs_difference_x > state.inches_to_pixels(state.inches_to_pixels(0.6 * state.person.wingspan)):
        diff += 0.5 * legs_difference_x
    diff += center_diff + scaled_difficulty_score + angle_diff + limb_strength_diff
    return diff

# %%
import numpy as np
from copy import copy
class aStar:
    WALL_HEIGHT = 180 #image.height -> divide that by height of wall in inches to get conversion
    def __init__(self, state):
        self.state = state
#         self.holds = route.holds
        self.reach = state.person.reach

    
                    
    def get_distance(self, hold, state):
        return np.sqrt((state[0] - hold[0]) ** 2 + (state[1] - hold[1]) ** 2)
    
    
        #return (1, "move")
    
    #def convert_pixel_to_inch(self):
        
    
#     def eval_action(self, state):
#         dict2 = {}
#         for limb in limbs:
#             for hold in self.route.holds:
#                 If dict1[limb].contains(hold):
#                     pass
#                 elif distance(limb.pos, hold.pos) >some number:
#                     pass
#                 else:
#                     difficulty = evaluation(action)
#                     dict2[(limb,hold)]= difficulty
#         return min(dict2)

    def getCostValue(self, costs):
        return sum([cost ** 2 for cost in costs])
        
    def uniformCostSearch(self):
        explored = []
        frontier = PriorityQueue()
        frontier.push(self.state, 0)
        while not frontier.isEmpty():
            cur_state = frontier.pop()
            #print(cur_state.moves)
            #print(f"Looking at state {cur_state}")
            explored.append(cur_state)
            if cur_state.lh.hold == self.state.route.finish_hold or cur_state.rh.hold == self.state.route.finish_hold:
                print("TAAAAAAAAAAAAAAKE")
                print(cur_state.lh.hold)
                print(cur_state.rh.hold)
                return cur_state.moves
            for next_state, action in cur_state.getStateSuccessors():
                if next_state not in explored: 
                    #print("not in explored")
                    next_state.costs = copy(cur_state.costs)
                    next_state.costs.append(stateDifficulty(next_state))
                    next_state.moves = copy(cur_state.moves)
                    next_state.moves.append(action)
                    #print(next_state.moves)
                    #print(frontier.heap)
                    if next_state in [tup[2] for tup in frontier.heap]:
                        frontier.update(next_state, self.getCostValue(next_state.costs))
                        #print(f"Updated {next_state} with {self.getCostValue(next_state.costs)}")
                    else:
                        frontier.push(next_state, self.getCostValue(next_state.costs))
                        #print(f"pushed {next_state} with {self.getCostValue(next_state.costs)}")

# %%
from get_holds import getHoldsArray
holds = getHoldsArray('../images/coolwall.jpg', [0, 40, 40], 15)
holds.sort()
print(holds)
# Out:
# image 1/1 /home/liaml/AI-Climbing/src/../images/coolwall.jpg: 1280x1184 97 holds, 1023.7ms
# Speed: 22.5ms preprocess, 1023.7ms inference, 3.8ms postprocess per image at shape (1, 3, 1280, 1184)
#
# 0: 64x64 three 0.51, two 0.32, eight 0.11, one 0.02, six 0.01, 45.8ms
# Speed: 2.7ms preprocess, 45.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.97, four 0.01, two 0.01, six 0.00, nine 0.00, 82.1ms
# Speed: 0.8ms preprocess, 82.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.80, six 0.11, two 0.05, three 0.02, four 0.01, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 64x64 seven 0.39, five 0.31, ten 0.16, nine 0.05, four 0.04, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.77, three 0.16, eight 0.03, one 0.01, two 0.01, 53.3ms
# Speed: 2.3ms preprocess, 53.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.60, two 0.20, five 0.05, four 0.04, three 0.04, 25.2ms
# Speed: 0.7ms preprocess, 25.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 eight 0.60, two 0.17, four 0.12, three 0.03, six 0.02, 35.9ms
# Speed: 2.2ms preprocess, 35.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.30, two 0.26, seven 0.14, eight 0.08, four 0.06, 323.1ms
# Speed: 1.0ms preprocess, 323.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.76, eight 0.16, nine 0.03, tag 0.02, ten 0.01, 19.7ms
# Speed: 0.8ms preprocess, 19.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 eight 0.60, seven 0.14, tag 0.12, one 0.05, nine 0.04, 30.7ms
# Speed: 0.8ms preprocess, 30.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.45, nine 0.29, seven 0.09, tag 0.07, eight 0.05, 27.7ms
# Speed: 0.6ms preprocess, 27.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.81, seven 0.04, ten 0.02, one 0.02, six 0.02, 243.3ms
# Speed: 0.9ms preprocess, 243.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.21, three 0.19, seven 0.15, tag 0.13, eight 0.11, 151.5ms
# Speed: 0.8ms preprocess, 151.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.78, six 0.20, two 0.01, four 0.01, nine 0.00, 11.8ms
# Speed: 0.8ms preprocess, 11.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.77, two 0.08, four 0.06, five 0.03, six 0.01, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.40, eight 0.31, nine 0.15, four 0.05, six 0.03, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.65, six 0.28, two 0.04, eight 0.01, tag 0.00, 15.7ms
# Speed: 0.8ms preprocess, 15.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.76, nine 0.08, eight 0.08, four 0.03, five 0.02, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.43, two 0.24, eight 0.07, four 0.07, three 0.05, 15.5ms
# Speed: 0.8ms preprocess, 15.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.98, nine 0.02, four 0.00, ten 0.00, six 0.00, 13.8ms
# Speed: 0.7ms preprocess, 13.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.58, seven 0.27, two 0.13, eight 0.01, tag 0.01, 18.9ms
# Speed: 0.7ms preprocess, 18.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.51, eight 0.20, four 0.16, six 0.07, nine 0.02, 14.7ms
# Speed: 0.7ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.28, five 0.25, seven 0.18, nine 0.14, four 0.06, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.45, tag 0.18, seven 0.17, four 0.05, eight 0.05, 13.2ms
# Speed: 0.8ms preprocess, 13.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.61, five 0.11, four 0.08, nine 0.08, tag 0.04, 12.7ms
# Speed: 1.1ms preprocess, 12.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 eight 0.43, seven 0.32, six 0.10, one 0.08, three 0.02, 17.7ms
# Speed: 1.6ms preprocess, 17.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.40, five 0.17, seven 0.11, nine 0.11, four 0.10, 10.9ms
# Speed: 0.6ms preprocess, 10.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 tag 0.70, seven 0.12, nine 0.05, four 0.05, eight 0.02, 13.9ms
# Speed: 0.7ms preprocess, 13.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.55, eight 0.29, seven 0.10, nine 0.03, six 0.02, 19.9ms
# Speed: 0.9ms preprocess, 19.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.37, seven 0.35, five 0.19, three 0.04, nine 0.03, 11.6ms
# Speed: 0.8ms preprocess, 11.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.67, four 0.22, seven 0.04, two 0.02, tag 0.01, 13.1ms
# Speed: 1.4ms preprocess, 13.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.55, eight 0.30, tag 0.08, two 0.02, four 0.01, 17.9ms
# Speed: 4.3ms preprocess, 17.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.68, four 0.29, two 0.01, eight 0.01, six 0.00, 11.8ms
# Speed: 0.7ms preprocess, 11.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.32, four 0.23, seven 0.18, eight 0.12, five 0.04, 18.1ms
# Speed: 1.1ms preprocess, 18.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.70, four 0.07, tag 0.06, three 0.04, one 0.04, 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.47, three 0.44, one 0.05, four 0.03, eight 0.01, 16.1ms
# Speed: 0.8ms preprocess, 16.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.67, one 0.09, tag 0.07, five 0.05, three 0.03, 59.2ms
# Speed: 2.3ms preprocess, 59.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 three 0.66, one 0.28, six 0.02, four 0.01, seven 0.01, 14.1ms
# Speed: 0.8ms preprocess, 14.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.73, seven 0.19, tag 0.02, ten 0.02, eight 0.02, 15.4ms
# Speed: 1.2ms preprocess, 15.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.72, eight 0.16, four 0.08, one 0.02, six 0.01, 16.4ms
# Speed: 1.1ms preprocess, 16.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.93, ten 0.02, tag 0.02, six 0.01, eight 0.01, 30.2ms
# Speed: 0.9ms preprocess, 30.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.56, eight 0.22, six 0.05, five 0.04, three 0.04, 16.8ms
# Speed: 1.2ms preprocess, 16.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.91, one 0.06, eight 0.02, six 0.00, tag 0.00, 13.1ms
# Speed: 0.8ms preprocess, 13.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.80, tag 0.07, eight 0.05, ten 0.03, four 0.02, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.90, seven 0.07, eight 0.02, two 0.01, tag 0.00, 100.4ms
# Speed: 0.9ms preprocess, 100.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.87, tag 0.05, four 0.03, eight 0.02, two 0.01, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.98, four 0.01, two 0.00, eight 0.00, six 0.00, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.36, ten 0.23, tag 0.11, five 0.10, two 0.07, 15.0ms
# Speed: 0.9ms preprocess, 15.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.75, two 0.12, seven 0.08, eight 0.03, one 0.01, 25.6ms
# Speed: 0.7ms preprocess, 25.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.38, ten 0.36, three 0.13, eight 0.06, seven 0.03, 13.2ms
# Speed: 0.9ms preprocess, 13.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.99, ten 0.00, seven 0.00, eight 0.00, three 0.00, 16.4ms
# Speed: 0.8ms preprocess, 16.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.40, three 0.30, eight 0.12, tag 0.07, one 0.06, 16.8ms
# Speed: 0.6ms preprocess, 16.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.68, tag 0.27, eight 0.03, four 0.01, ten 0.01, 17.0ms
# Speed: 0.9ms preprocess, 17.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.34, eight 0.24, three 0.18, seven 0.11, four 0.05, 15.7ms
# Speed: 1.2ms preprocess, 15.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.60, seven 0.36, eight 0.01, tag 0.01, four 0.00, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.76, seven 0.09, two 0.05, three 0.04, four 0.03, 16.7ms
# Speed: 1.1ms preprocess, 16.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 one 0.37, ten 0.34, seven 0.08, eight 0.07, six 0.03, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.60, five 0.19, ten 0.11, nine 0.04, eight 0.02, 17.3ms
# Speed: 1.2ms preprocess, 17.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.87, six 0.08, downclimb 0.02, ten 0.01, eight 0.01, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.43, five 0.41, ten 0.10, nine 0.02, tag 0.02, 17.5ms
# Speed: 0.7ms preprocess, 17.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.35, ten 0.28, five 0.24, two 0.08, six 0.02, 17.8ms
# Speed: 0.7ms preprocess, 17.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.64, five 0.19, ten 0.07, eight 0.04, four 0.02, 17.4ms
# Speed: 1.1ms preprocess, 17.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.24, five 0.21, six 0.17, one 0.11, tag 0.09, 14.8ms
# Speed: 0.7ms preprocess, 14.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.71, seven 0.13, downclimb 0.06, five 0.03, two 0.02, 16.1ms
# Speed: 0.7ms preprocess, 16.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.43, eight 0.17, five 0.17, ten 0.12, nine 0.03, 18.5ms
# Speed: 0.7ms preprocess, 18.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.55, five 0.14, eight 0.14, two 0.05, four 0.04, 18.8ms
# Speed: 0.6ms preprocess, 18.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.76, ten 0.08, nine 0.07, eight 0.04, four 0.02, 18.7ms
# Speed: 0.7ms preprocess, 18.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.72, seven 0.14, downclimb 0.06, eight 0.04, six 0.01, 95.7ms
# Speed: 0.8ms preprocess, 95.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.72, ten 0.10, five 0.06, eight 0.06, six 0.03, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.98, five 0.01, seven 0.00, eight 0.00, two 0.00, 16.3ms
# Speed: 0.9ms preprocess, 16.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 four 0.75, eight 0.16, six 0.07, seven 0.01, downclimb 0.00, 27.1ms
# Speed: 0.7ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.65, seven 0.30, eight 0.02, four 0.01, nine 0.01, 30.3ms
# Speed: 0.8ms preprocess, 30.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.90, eight 0.05, seven 0.02, bolt 0.01, three 0.00, 18.5ms
# Speed: 1.1ms preprocess, 18.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.75, eight 0.07, five 0.06, four 0.05, nine 0.02, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 six 0.75, seven 0.14, eight 0.07, ten 0.02, four 0.02, 31.5ms
# Speed: 1.2ms preprocess, 31.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.45, five 0.27, eight 0.15, four 0.07, six 0.02, 19.2ms
# Speed: 0.9ms preprocess, 19.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 two 0.53, four 0.25, seven 0.16, six 0.02, one 0.02, 18.4ms
# Speed: 0.7ms preprocess, 18.4ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.97, six 0.02, three 0.01, eight 0.00, four 0.00, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.75, seven 0.15, eight 0.03, four 0.02, three 0.01, 14.6ms
# Speed: 0.7ms preprocess, 14.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.41, one 0.41, six 0.14, two 0.01, four 0.01, 16.5ms
# Speed: 0.9ms preprocess, 16.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.92, eight 0.06, tag 0.00, four 0.00, five 0.00, 16.2ms
# Speed: 1.1ms preprocess, 16.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.94, six 0.03, eight 0.02, one 0.00, three 0.00, 14.4ms
# Speed: 1.2ms preprocess, 14.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.78, four 0.09, five 0.06, eight 0.03, three 0.02, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.68, eight 0.10, three 0.09, six 0.05, four 0.04, 18.8ms
# Speed: 0.8ms preprocess, 18.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 1.00, eight 0.00, two 0.00, three 0.00, downclimb 0.00, 19.5ms
# Speed: 0.7ms preprocess, 19.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.97, ten 0.01, five 0.01, nine 0.00, eight 0.00, 22.5ms
# Speed: 0.8ms preprocess, 22.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.81, five 0.10, tag 0.05, ten 0.02, one 0.01, 19.2ms
# Speed: 0.7ms preprocess, 19.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.94, five 0.03, ten 0.01, eight 0.01, three 0.01, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 1.00, eight 0.00, downclimb 0.00, two 0.00, tag 0.00, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.79, ten 0.11, five 0.02, six 0.02, nine 0.02, 27.8ms
# Speed: 0.7ms preprocess, 27.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.63, two 0.17, tag 0.06, six 0.05, five 0.04, 20.9ms
# Speed: 0.6ms preprocess, 20.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.30, ten 0.27, eight 0.15, nine 0.12, one 0.06, 14.1ms
# Speed: 2.8ms preprocess, 14.1ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.69, five 0.11, eight 0.08, ten 0.05, nine 0.03, 82.8ms
# Speed: 0.8ms preprocess, 82.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.34, nine 0.29, eight 0.20, ten 0.08, six 0.03, 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.52, ten 0.18, nine 0.12, eight 0.08, five 0.03, 40.2ms
# Speed: 1.5ms preprocess, 40.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.70, seven 0.17, six 0.08, two 0.01, downclimb 0.01, 26.2ms
# Speed: 0.6ms preprocess, 26.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.55, ten 0.17, eight 0.11, five 0.10, three 0.02, 19.7ms
# Speed: 0.7ms preprocess, 19.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.52, seven 0.12, five 0.07, two 0.07, nine 0.06, 30.7ms
# Speed: 1.9ms preprocess, 30.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.76, nine 0.10, eight 0.09, seven 0.03, three 0.01, 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.51, eight 0.27, nine 0.09, tag 0.07, seven 0.02, 23.6ms
# Speed: 2.1ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 nine 0.77, tag 0.13, eight 0.08, ten 0.01, bolt 0.00, 23.3ms
# Speed: 0.7ms preprocess, 23.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.57, tag 0.13, eight 0.09, nine 0.08, seven 0.08, 35.1ms
# Speed: 0.6ms preprocess, 35.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.69, seven 0.24, nine 0.04, eight 0.01, five 0.00, 21.7ms
# Speed: 0.7ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.86, three 0.05, nine 0.04, eight 0.01, five 0.01, 20.4ms
# Speed: 0.7ms preprocess, 20.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 ten 0.75, seven 0.13, six 0.05, nine 0.05, five 0.02, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 eight 0.44, downclimb 0.16, three 0.12, seven 0.07, four 0.06, 16.6ms
# Speed: 0.6ms preprocess, 16.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.67, five 0.18, eight 0.07, nine 0.02, ten 0.02, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 five 0.26, ten 0.24, eight 0.22, tag 0.09, nine 0.04, 24.7ms
# Speed: 1.4ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.42, eight 0.38, nine 0.06, three 0.06, five 0.03, 23.0ms
# Speed: 0.8ms preprocess, 23.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.62, eight 0.14, two 0.12, three 0.07, ten 0.02, 84.3ms
# Speed: 0.7ms preprocess, 84.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 seven 0.69, ten 0.12, five 0.07, nine 0.05, six 0.03, 23.7ms
# Speed: 0.8ms preprocess, 23.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
#
# 0: 64x64 tag 0.48, two 0.18, seven 0.10, eight 0.09, six 0.05, 26.4ms
# Speed: 1.3ms preprocess, 26.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# [Hold: Top left at 2526.410888671875, 364.408203125
#                 Width = 73.39794921875, Height = 63.4354248046875
#                 Difficulty = 6.55/10, Angle = 0 degrees
# , Hold: Top left at 659.6800537109375, 582.14892578125
#                 Width = 206.08453369140625, Height = 246.58389282226562
#                 Difficulty = 6.54/10, Angle = 315 degrees
# , Hold: Top left at 943.9332885742188, 808.7345581054688
#                 Width = 389.4359130859375, Height = 319.4248046875
#                 Difficulty = 3.98/10, Angle = 0 degrees
# , Hold: Top left at 999.0489501953125, 1112.322998046875
#                 Width = 388.56964111328125, Height = 317.5919189453125
#                 Difficulty = 6.21/10, Angle = 0 degrees
# , Hold: Top left at 927.7785034179688, 1391.28466796875
#                 Width = 169.1075439453125, Height = 187.1275634765625
#                 Difficulty = 7.9/10, Angle = 315 degrees
# , Hold: Top left at 1364.2099609375, 1457.0947265625
#                 Width = 250.6278076171875, Height = 307.965576171875
#                 Difficulty = 3.55/10, Angle = 315 degrees
# , Hold: Top left at 720.4488525390625, 1724.419677734375
#                 Width = 182.13848876953125, Height = 107.5181884765625
#                 Difficulty = 5.14/10, Angle = 0 degrees
# , Hold: Top left at 1451.65185546875, 1729.7177734375
#                 Width = 498.0777587890625, Height = 327.4664306640625
#                 Difficulty = 6.95/10, Angle = 0 degrees
# , Hold: Top left at 1345.602783203125, 2012.46728515625
#                 Width = 239.4896240234375, Height = 212.4183349609375
#                 Difficulty = 2.55/10, Angle = 135 degrees
# , Hold: Top left at 800.716796875, 2018.7711181640625
#                 Width = 77.246826171875, Height = 79.774169921875
#                 Difficulty = 6.32/10, Angle = 270 degrees
# , Hold: Top left at 726.4889526367188, 2301.441162109375
#                 Width = 223.3643798828125, Height = 187.28076171875
#                 Difficulty = 3.91/10, Angle = 0 degrees
# , Hold: Top left at 1172.28759765625, 2393.466796875
#                 Width = 84.04736328125, Height = 87.01318359375
#                 Difficulty = 10.0/10, Angle = 0 degrees
# , Hold: Top left at 768.2841796875, 2429.41943359375
#                 Width = 78.12127685546875, Height = 66.861328125
#                 Difficulty = 7.0/10, Angle = 0 degrees
# , Hold: Top left at 1165.5316162109375, 2583.464111328125
#                 Width = 99.3564453125, Height = 54.19677734375
#                 Difficulty = 9.94/10, Angle = 90 degrees
# , Hold: Top left at 1349.177734375, 2772.248046875
#                 Width = 102.7601318359375, Height = 63.711669921875
#                 Difficulty = 8.55/10, Angle = 180 degrees
# , Hold: Top left at 1241.4046630859375, 3045.58984375
#                 Width = 159.59765625, Height = 250.53564453125
#                 Difficulty = 6.35/10, Angle = 135 degrees
# ]

# %%
route = Route(holds = holds, start1 = holds[-6], start2 = holds[-6], finish = holds[1])
lh = Limb(LimbName.LEFT_HAND, 2.5, 8, route.start_hold1)
rh = Limb(LimbName.RIGHT_HAND, 2.5, 8, route.start_hold1)
lf = Limb(LimbName.LEFT_LEG, 8, 5, route.holds[-1])
rf = Limb(LimbName.RIGHT_LEG, 8, 5, route.holds[-1])
ondra = Person(100)
state = State(lf, rf, lh, rh, ondra, route)
a_star = aStar(state)
print(a_star.uniformCostSearch())
# Out:
# TAAAAAAAAAAAAAAKE
# Hold: Top left at 1345.602783203125, 2012.46728515625
#                 Width = 239.4896240234375, Height = 212.4183349609375
#                 Difficulty = 2.55/10, Angle = 135 degrees
#
# Hold: Top left at 659.6800537109375, 582.14892578125
#                 Width = 206.08453369140625, Height = 246.58389282226562
#                 Difficulty = 6.54/10, Angle = 315 degrees
#
# [(LimbName.LEFT_HAND at Hold: Top left at 726.4889526367188, 2301.441162109375
#                 Width = 223.3643798828125, Height = 187.28076171875
#                 Difficulty = 3.91/10, Angle = 0 degrees
# , Hold: Top left at 1451.65185546875, 1729.7177734375
#                 Width = 498.0777587890625, Height = 327.4664306640625
#                 Difficulty = 6.95/10, Angle = 0 degrees
# ), (LimbName.LEFT_LEG at Hold: Top left at 1241.4046630859375, 3045.58984375
#                 Width = 159.59765625, Height = 250.53564453125
#                 Difficulty = 6.35/10, Angle = 135 degrees
# , Hold: Top left at 768.2841796875, 2429.41943359375
#                 Width = 78.12127685546875, Height = 66.861328125
#                 Difficulty = 7.0/10, Angle = 0 degrees
# ), (LimbName.LEFT_HAND at Hold: Top left at 726.4889526367188, 2301.441162109375
#                 Width = 223.3643798828125, Height = 187.28076171875
#                 Difficulty = 3.91/10, Angle = 0 degrees
# , Hold: Top left at 1345.602783203125, 2012.46728515625
#                 Width = 239.4896240234375, Height = 212.4183349609375
#                 Difficulty = 2.55/10, Angle = 135 degrees
# ), (LimbName.RIGHT_HAND at Hold: Top left at 726.4889526367188, 2301.441162109375
#                 Width = 223.3643798828125, Height = 187.28076171875
#                 Difficulty = 3.91/10, Angle = 0 degrees
# , Hold: Top left at 659.6800537109375, 582.14892578125
#                 Width = 206.08453369140625, Height = 246.58389282226562
#                 Difficulty = 6.54/10, Angle = 315 degrees
# )]

# %%
hi = np.array([(0, 0, 1), (0, 0, 1)])
print(hi[:, 2])
# Out:
# [1 1]

# %%
print(holds[-6])
# Out:
# Hold: Top left at 726.4889526367188, 2301.441162109375
#                 Width = 223.3643798828125, Height = 187.28076171875
#                 Difficulty = 3.91/10, Angle = 0 degrees
